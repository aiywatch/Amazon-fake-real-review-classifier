# %% [markdown]
# ## question 4

# %%
import csv                               # csv reader
from sklearn.svm import LinearSVC
from nltk.classify import SklearnClassifier, accuracy
from random import shuffle
from sklearn.pipeline import Pipeline
import math
import numpy as np
from sklearn.metrics import precision_recall_fscore_support
from nltk.tokenize import word_tokenize, sent_tokenize, RegexpTokenizer
from nltk.stem import SnowballStemmer
from sklearn.model_selection import KFold
from sklearn.feature_extraction.text import CountVectorizer
from nltk.corpus import stopwords
import string

# %%
# load data from a file and append it to the rawData
def loadData(path, Text=None):
    with open(path) as f:
        reader = csv.reader(f, delimiter='\t')
        for line in reader:
            (Id, Text, Label) = parseReview(line)
            rawData.append((Id, Text, Label))
            preprocessedData.append((Id, preProcess(Text), Label))
        
def splitData(percentage):
    dataSamples = len(rawData)
    halfOfData = int(len(rawData)/2)
    trainingSamples = int((percentage*dataSamples)/2)
    for (_, Text, Label) in rawData[:trainingSamples] + rawData[halfOfData:halfOfData+trainingSamples]:
        trainData.append((toFeatureVector(preProcess(Text)),Label))
    for (_, Text, Label) in rawData[trainingSamples:halfOfData] + rawData[halfOfData+trainingSamples:]:
        testData.append((toFeatureVector(preProcess(Text)),Label))

# QUESTION 1
# Convert line from input file into an id/text/label tuple
def parseReview(reviewLine):
    # Should return a triple of an integer, a string containing the review, and a string indicating the label
#     print(reviewLine)
#     result = reviewLine.split('\t')
    if reviewLine[1] == '__label1__':
        label = 'fake'
    else:
        label = 'real'
    return (reviewLine[0], reviewLine[8], label)

stemmer = SnowballStemmer('english')
stopWords = set(stopwords.words('english'))
tokenizer = RegexpTokenizer(r'\w+')

# Input: a string of one review
def preProcess(text):
    # Should return a list of tokens
#     tokens = word_tokenize(text)
    tokens = tokenizer.tokenize(text)
    result = [stemmer.stem(t) for t in tokens if t not in stopWords]
    return result

# QUESTION 2
vectorizer = CountVectorizer()

featureDict = {} # A global dictionary of features

# def toFeatureVector(tokens):
#     # Should return a dictionary containing features as keys, and weights as values
# #     text_vec = vectorizer.fit_transform(tokens)
# # text_vec.toarray()
#     feature_vector = {}
#     for token in tokens:
#         if token in feature_vector:
#             feature_vector[token] += 1
#         else:
#             feature_vector[token] = 1
        
#         if token in featureDict:
#             featureDict[token] += 1
#         else:
#             featureDict[token] = 1
            
#     return feature_vector

def toFeatureVector(tokens):
    feature_vector = {}
    for i in range(len(tokens)-1):
        token = (tokens[i], tokens[i+1])
        if token in feature_vector:
            feature_vector[token] += 1
        else:
            feature_vector[token] = 1
        
        if token in featureDict:
            featureDict[token] += 1
        else:
            featureDict[token] = 1
            
    return feature_vector

# TRAINING AND VALIDATING OUR CLASSIFIER
def trainClassifier(trainData):
    print("Training Classifier...")
    pipeline =  Pipeline([('svc', LinearSVC(loss='hinge', max_iter=3000, C=1))])
    return SklearnClassifier(pipeline).train(trainData)

# PREDICTING LABELS GIVEN A CLASSIFIER

def predictLabels(reviewSamples, classifier):
    return classifier.classify_many(map(lambda t: toFeatureVector(preProcess(t[1])), reviewSamples))

def predictLabels_cv(reviewSamples, classifier):
    return classifier.classify_many(map(lambda t: t[0], reviewSamples))

def predictLabel(reviewSample, classifier):
    return classifier.classify(toFeatureVector(preProcess(reviewSample)))

# QUESTION 3
def crossValidate(dataset, folds):
    shuffle(dataset)
    cv_results = []
    foldSize = math.ceil(len(dataset)/folds)
    
    kf = KFold(n_splits=folds)
    
    scores = np.array([0,0,0,0])
    
    for train_index, test_index in kf.split(dataset):
        X_train, X_test = dataset[train_index], dataset[test_index]
        classifier = trainClassifier(X_train)
        y_pred = predictLabels_cv(X_test, classifier)
        y_true = X_test[:, 1]
        
        acc = accuracy(classifier, X_test)
        prfs = precision_recall_fscore_support(y_true, y_pred, average='weighted')
        scores = scores + np.array([prfs[0], prfs[1], prfs[2], acc])

    scores = scores / folds
    cv_results = {'precision': scores[0], 'recall': scores[1],
                  'f1': scores[2], 'accuracy': scores[3]}
    return cv_results

# %%
# loading reviews
rawData = []          # the filtered data from the dataset file (should be 21000 samples)
preprocessedData = [] # the preprocessed reviews (just to see how your preprocessing is doing)
trainData = []        # the training data as a percentage of the total dataset (currently 80%, or 16800 samples)
testData = []         # the test data as a percentage of the total dataset (currently 20%, or 4200 samples)

# references to the data files
reviewPath = 'amazon_reviews.txt'

print("Now %d rawData, %d trainData, %d testData" % (len(rawData), len(trainData), len(testData)),
      "Preparing the dataset...",sep='\n')
loadData(reviewPath) 
rawData = rawData[1:]
preprocessedData = preprocessedData[1:]
# We split the raw dataset into a set of training data and a set of test data (80/20)
print("Now %d rawData, %d trainData, %d testData" % (len(rawData), len(trainData), len(testData)),
      "Preparing training and test data...",sep='\n')
splitData(0.8)
# We print the number of training samples and the number of features
print("Now %d rawData, %d trainData, %d testData" % (len(rawData), len(trainData), len(testData)),
      "Training Samples: ", len(trainData), "Features: ", len(featureDict), sep='\n')
# Out:
# Now 0 rawData, 0 trainData, 0 testData
# Preparing the dataset...
# Now 21000 rawData, 0 trainData, 0 testData
# Preparing training and test data...
# Now 21000 rawData, 16800 trainData, 4200 testData
# Training Samples:
# 16800
# Features:
# 426026

# %%
train_np = np.array(trainData)
print('train no',len(trainData))
crossValidate(train_np, 3)
# Out:
# train no 16800
# Training Classifier...
# /home/aiy/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1137: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples.
#   'recall', 'true', average, warn_for)
# Training Classifier...
# Training Classifier...
# {'accuracy': 0.85351190476190475,
#  'f1': 0.81643658745541003,
#  'precision': 0.90290037659461564,
#  'recall': 0.85351190476190475}

# %%
trainData
# Out:
# [({('around', 'case'): 1,
#    ('case', 'need'): 1,
#    ('day', 'just'): 1,
#    ('just', 'keep'): 1,
#    ('keep', 'around'): 1,
#    ('least', 'think'): 1,
#    ('need', 'someth'): 1,
#    ('product', 'save'): 1,
#    ('save', 'day'): 1,
#    ('think', 'product'): 1,
#    ('when', 'least'): 1},
#   'fake'),
#  ({('act', 'like'): 1,
#    ('assist', 'act'): 1,
#    ('averag', 'develop'): 1,
#    ('batteri', 'keep'): 1,
#    ('batteri', 'someth'): 1,
#    ('best', 'low'): 1,
#    ('br', 'there'): 1,
#    ('built', 'technic'): 1,
#    ('charg', 'work'): 1,
#    ('compromis', 'qualiti'): 1,
#    ('cost', 'br'): 1,
#    ('cost', 'relat'): 1,
#    ('develop', 'cost'): 1,
#    ('everi', 'voltag'): 1,
#    ('forté', 'the'): 1,
#    ('high', 'stallion'): 1,
#    ('high', 'voltag'): 1,
#    ('introduc', 'market'): 1,
#    ('keep', 'phone'): 1,
#    ('like', 'sensor'): 1,
#    ('lithium', 'batteri'): 1,
#    ('low', 'cost'): 1,
#    ('mani', 'built'): 1,
#    ('market', 'averag'): 1,
#    ('never', 'risk'): 1,
#    ('new', 'introduc'): 1,
#    ('particular', 'forté'): 1,
#    ('phone', 'charg'): 1,
#    ('provid', 'us'): 1,
#    ('qualiti', 'provid'): 1,
#    ('relat', 'high'): 1,
#    ('sensor', 'particular'): 1,
#    ('someth', 'new'): 1,
#    ('stallion', 'compromis'): 1,
#    ('technic', 'assist'): 1,
#    ('the', 'batteri'): 1,
#    ('there', 'mani'): 1,
#    ('us', 'best'): 1,
#    ('voltag', 'high'): 1,
#    ('voltag', 'never'): 1,
#    ('work', 'everi'): 1},
#   'fake'),
#  ({('6', 'month'): 1,
#    ('babi', 'she'): 1,
#    ('beauti', 'though'): 1,
#    ('color', 'lot'): 1,
#    ('grown', 'it'): 1,
#    ('i', 'love'): 1,
#    ('i', 'purchas'): 1,
#    ('i', 'think'): 1,
#    ('it', 'beauti'): 1,
#    ('it', 'loud'): 1,
#    ('lot', 'set'): 1,
#    ('loud', 'swing'): 1,
#    ('love', 'color'): 1,
#    ('month', 'pretti'): 1,
#    ('much', 'grown'): 1,
#    ('pretti', 'much'): 1,
#    ('purchas', 'swing'): 1,
#    ('set', 'i'): 1,
#    ('she', '6'): 1,
#    ('swing', 'babi'): 1,
#    ('swing', 'well'): 1,
#    ('think', 'worth'): 1,
#    ('though', 'i'): 1,
#    ('well', 'it'): 1,
#    ('worth', 'money'): 1},
#   'fake'),
#  ({('big', 'deal'): 1,
#    ('bit', 'not'): 1,
#    ('calcolatur', 'it'): 1,
#    ('desk', 'calcolatur'): 1,
#    ('everyth', 'i'): 1,
#    ('hit', 'key'): 1,
#    ('i', 'hit'): 1,
#    ('i', 'look'): 1,
#    ('i', 'need'): 1,
#    ('inexpens', 'desk'): 1,
#    ('issu', 'tilt'): 1,
#    ('it', 'work'): 1,
#    ('key', 'rock'): 1,
#    ('littl', 'bit'): 1,
#    ('look', 'inexpens'): 1,
#    ('need', 'onli'): 1,
#    ('not', 'big'): 1,
#    ('one', 'side'): 1,
#    ('onli', 'issu'): 1,
#    ('rock', 'littl'): 1,
#    ('side', 'i'): 1,
#    ('slight', 'one'): 1,
#    ('tilt', 'slight'): 1,
#    ('work', 'everyth'): 1},
#   'fake'),
#  ({('also', 'techniqu'): 1,
#    ('everyth', 'teeth'): 1,
#    ('great', 'i'): 1,
#    ('i', 'use'): 2,
#    ('i', 'would'): 1,
#    ('keep', 'everyth'): 1,
#    ('keep', 'use'): 1,
#    ('least', 'three'): 1,
#    ('potenc', 'solut'): 1,
#    ('result', 'great'): 1,
#    ('result', 'i'): 1,
#    ('solut', 'also'): 1,
#    ('solut', 'result'): 1,
#    ('techniqu', 'tray'): 1,
#    ('teeth', 'mouth'): 1,
#    ('teeth', 'whiten'): 1,
#    ('three', 'time'): 1,
#    ('time', 'week'): 1,
#    ('tray', 'keep'): 1,
#    ('twice', 'week'): 1,
#    ('use', 'least'): 1,
#    ('use', 'potenc'): 1,
#    ('use', 'teeth'): 1,
#    ('use', 'twice'): 1,
#    ('week', 'result'): 1,
#    ('week', 'will'): 1,
#    ('whiten', 'solut'): 1,
#    ('will', 'keep'): 1,
#    ('would', 'use'): 1},
#   'fake'),
#  ({('cultur', 'use'): 1,
#    ('gift', 'use'): 1,
#    ('give', 'gift'): 1,
#    ('i', 'sure'): 1,
#    ('i', 'would'): 1,
#    ('littl', 'research'): 1,
#    ('pipe', 'plan'): 1,
#    ('plan', 'give'): 1,
#    ('recommend', 'littl'): 1,
#    ('research', 'cultur'): 1,
#    ('suppos', 'i'): 1,
#    ('sure', 'suppos'): 1,
#    ('use', 'pipe'): 1,
#    ('would', 'recommend'): 1},
#   'fake'),
#  ({('11', 'year'): 1,
#    ('13', 'year'): 1,
#    ('a', 'friend'): 1,
#    ('believ', 'challeng'): 1,
#    ('better', 'kid'): 1,
#    ('blast', 'plus'): 1,
#    ('challeng', 'noth'): 1,
#    ('could', 'handl'): 1,
#    ('day', 'a'): 1,
#    ('entertain', 'plus'): 1,
#    ('famili', 'entertain'): 1,
#    ('friend', 'put'): 1,
#    ('game', 'day'): 1,
#    ('i', 'believ'): 1,
#    ('kid', 'sit'): 1,
#    ('lot', 'famili'): 1,
#    ('noth', 'could'): 1,
#    ('old', '13'): 1,
#    ('old', 'blast'): 1,
#    ('ping', 'pong'): 1,
#    ('pleas', 'ping'): 1,
#    ('plus', 'better'): 1,
#    ('plus', 'lot'): 1,
#    ('pong', 'tabl'): 1,
#    ('put', 'togeth'): 1,
#    ('sit', 'video'): 1,
#    ('tabl', '11'): 1,
#    ('togeth', 'i'): 1,
#    ('video', 'game'): 1,
#    ('year', 'old'): 2},
#   'fake'),
#  ({('bite', 'help'): 1,
#    ('bug', 'bite'): 1,
#    ('c', 'serum'): 1,
#    ('faster', 'normal'): 1,
#    ('feel', 'sticki'): 1,
#    ('great', 'vitamin'): 1,
#    ('heal', 'skin'): 1,
#    ('help', 'heal'): 1,
#    ('i', 'realli'): 1,
#    ('i', 'use'): 1,
#    ('last', 'week'): 1,
#    ('like', 'oil'): 1,
#    ('oil', 'feel'): 1,
#    ('realli', 'like'): 1,
#    ('recent', 'bug'): 1,
#    ('serum', 'i'): 1,
#    ('skin', 'faster'): 1,
#    ('sticki', 'i'): 1,
#    ('use', 'last'): 1,
#    ('vitamin', 'c'): 1,
#    ('week', 'recent'): 1},
#   'fake'),
#  ({('cloth', 'smell'): 1,
#    ('deterg', 'mani'): 1,
#    ('deterg', 'use'): 1,
#    ('great', 'deterg'): 1,
#    ('i', 'use'): 1,
#    ('laundri', 'deterg'): 1,
#    ('leaver', 'cloth'): 1,
#    ('mani', 'year'): 1,
#    ('nice', 'scent'): 1,
#    ('pod', 'laundri'): 1,
#    ('scent', 'leaver'): 1,
#    ('smell', 'fresh'): 1,
#    ('tide', 'pod'): 1,
#    ('use', 'nice'): 1,
#    ('use', 'tide'): 1,
#    ('year', 'great'): 1},
#   'fake'),
#  ({('amateur', 'label'): 1,
#    ('amateur', 'stuff'): 1,
#    ('ask', 'would'): 1,
#    ('brand', 'even'): 1,
#    ('but', 'relat'): 1,
#    ('compani', 'look'): 1,
#    ('don', 'wast'): 1,
#    ('even', 'say'): 1,
#    ('everybodi', 'want'): 1,
#    ('exist', 'compani'): 1,
#    ('fall', 'promis'): 1,
#    ('kind', 'amateur'): 1,
#    ('label', 'product'): 1,
#    ('look', 'amateur'): 1,
#    ('no', 'way'): 1,
#    ('non', 'exist'): 1,
#    ('product', 'you'): 1,
#    ('promis', 'but'): 1,
#    ('relat', 'unheard'): 1,
#    ('say', 'non'): 1,
#    ('stuff', 'no'): 1,
#    ('trust', 'kind'): 1,
#    ('unheard', 'brand'): 1,
#    ('want', 'fall'): 1,
#    ('wast', 'money'): 1,
#    ('way', 'don'): 1,
#    ('would', 'trust'): 1,
#    ('you', 'ask'): 1},
#   'fake'),
#  ({('i', 'tri'): 1,
#    ('made', 'sick'): 1,
#    ('sick', 'throw'): 1,
#    ('they', 'made'): 1,
#    ('throw', 'two'): 1,
#    ('time', 'i'): 1,
#    ('two', 'time'): 1,
#    ('unfortun', 'work'): 1,
#    ('work', 'they'): 1},
#   'fake'),
#  ({('daughter', 'she'): 1,
#    ('design', 'nice'): 1,
#    ('easi', 'use'): 1,
#    ('gift', 'daughter'): 1,
#    ('kettl', 'gift'): 1,
#    ('like', 'design'): 1,
#    ('nice', 'neat'): 1,
#    ('said', 'easi'): 1,
#    ('she', 'like'): 1,
#    ('she', 'said'): 1,
#    ('this', 'kettl'): 1,
#    ('use', 'she'): 1},
#   'fake'),
#  ({('cold', 'good'): 1,
#    ('complement', 'sleek'): 1,
#    ('doesnt', 'leav'): 1,
#    ('dri', 'well'): 1,
#    ('drink', 'warm'): 1,
#    ('drip', 'lid'): 1,
#    ('especi', 'doesnt'): 1,
#    ('fingerprint', 'high'): 1,
#    ('get', 'complement'): 1,
#    ('good', 'period'): 1,
#    ('high', 'recommend'): 1,
#    ('i', 'get'): 1,
#    ('i', 'love'): 1,
#    ('keep', 'drink'): 1,
#    ('leav', 'fingerprint'): 1,
#    ('lid', 'sure'): 1,
#    ('lid', 'tumbler'): 1,
#    ('look', 'time'): 1,
#    ('love', 'tumbler'): 1,
#    ('onli', 'suggest'): 1,
#    ('period', 'time'): 1,
#    ('prevent', 'drip'): 1,
#    ('recommend', 'onli'): 1,
#    ('shake', 'dri'): 1,
#    ('sleek', 'look'): 1,
#    ('sturdi', 'i'): 1,
#    ('suggest', 'wash'): 1,
#    ('sure', 'shake'): 1,
#    ('time', 'especi'): 1,
#    ('time', 'sturdi'): 1,
#    ('tumbler', 'keep'): 1,
#    ('warm', 'cold'): 1,
#    ('wash', 'lid'): 1,
#    ('well', 'prevent'): 1},
#   'fake'),
#  ({('3', 'star'): 1,
#    ('5', 'htp'): 1,
#    ('ad', 'get'): 1,
#    ('anxieti', 'kava'): 1,
#    ('anxieti', 'panic'): 1,
#    ('anxieti', 'stress'): 1,
#    ('asin', 'b00hbgbry4'): 1,
#    ('attack', 'boost'): 1,
#    ('attack', 'save'): 1,
#    ('b00hbgbry4', 'zenrx'): 1,
#    ('back', 'guarante'): 1,
#    ('beat', 'anxieti'): 1,
#    ('boost', 'mood'): 1,
#    ('cheap', 'has'): 1,
#    ('day', 'differ'): 1,
#    ('depress', 'panic'): 1,
#    ('dietari', 'supplement'): 1,
#    ('differ', 'asin'): 1,
#    ('effect', 'pretti'): 1,
#    ('gaba', 'money'): 1,
#    ('get', 'zenrx'): 1,
#    ('give', '3'): 1,
#    ('has', 'mild'): 1,
#    ('htp', 'theanin'): 1,
#    ('increas', 'relax'): 1,
#    ('kava', '5'): 1,
#    ('kava', 'kava'): 1,
#    ('mild', 'sedat'): 1,
#    ('money', 'ad'): 1,
#    ('money', 'back'): 1,
#    ('mood', 'increas'): 1,
#    ('night', 'day'): 1,
#    ('onli', 'give'): 1,
#    ('panic', 'attack'): 2,
#    ('pretti', 'useless'): 1,
#    ('reduc', 'symptom'): 1,
#    ('relax', 'beat'): 1,
#    ('save', 'money'): 1,
#    ('sedat', 'effect'): 1,
#    ('star', 'cheap'): 1,
#    ('stress', 'anxieti'): 1,
#    ('stress', 'depress'): 1,
#    ('supplement', 'reduc'): 1,
#    ('symptom', 'anxieti'): 1,
#    ('theanin', 'gaba'): 1,
#    ('useless', 'stress'): 1,
#    ('zenrx', 'dietari'): 1,
#    ('zenrx', 'night'): 1},
#   'fake'),
#  ({('2', 'brown'): 1,
#    ('accur', 'descript'): 1,
#    ('around', 'great'): 1,
#    ('bar', 'counter'): 1,
#    ('bought', '2'): 1,
#    ('brown', 'island'): 1,
#    ('chair', 'would'): 1,
#    ('color', 'accur'): 1,
#    ('counter', 'kitchen'): 1,
#    ('definit', 'chair'): 1,
#    ('descript', 'there'): 1,
#    ('fail', 'use'): 1,
#    ('great', 'bar'): 1,
#    ('hydraul', 'mechan'): 1,
#    ('i', 'bought'): 1,
#    ('i', 'realli'): 1,
#    ('island', 'the'): 1,
#    ('like', 'the'): 1,
#    ('look', 'though'): 1,
#    ('loung', 'around'): 1,
#    ('mechan', 'look'): 1,
#    ('might', 'fail'): 1,
#    ('much', 'definit'): 1,
#    ('otherwis', 'i'): 1,
#    ('pad', 'much'): 1,
#    ('realli', 'like'): 1,
#    ('the', 'color'): 1,
#    ('the', 'hydraul'): 1,
#    ('there', 'pad'): 1,
#    ('though', 'might'): 1,
#    ('use', 'otherwis'): 1,
#    ('would', 'loung'): 1},
#   'fake'),
#  ({('5', 'month'): 1,
#    ('also', 'great'): 1,
#    ('clear', 'loud'): 1,
#    ('ear', 'love'): 1,
#    ('great', 'also'): 1,
#    ('great', 'price'): 1,
#    ('headphon', '5'): 1,
#    ('headphon', 'mention'): 1,
#    ('loud', 'soft'): 1,
#    ('love', 'headphon'): 1,
#    ('mention', 'soni'): 1,
#    ('month', 'work'): 1,
#    ('price', 'sound'): 1,
#    ('soft', 'ear'): 1,
#    ('sound', 'clear'): 1,
#    ('wonder', 'headphon'): 1,
#    ('work', 'great'): 1},
#   'fake'),
#  ({('believ', 'enhanc'): 1,
#    ('camera', 'place'): 1,
#    ('camera', 'side'): 1,
#    ('driver', 'side'): 1,
#    ('due', 'left'): 1,
#    ('enhanc', 'gripe'): 1,
#    ('fine', 'look'): 1,
#    ('fit', 'fine'): 1,
#    ('gripe', 'i'): 1,
#    ('happi', 'far'): 1,
#    ('i', 'believ'): 1,
#    ('i', 'say'): 1,
#    ('i', 'wish'): 1,
#    ('left', 'camera'): 1,
#    ('like', 'real'): 1,
#    ('look', 'like'): 1,
#    ('mirror', 'i'): 1,
#    ('one', 'one'): 1,
#    ('one', 'side'): 1,
#    ('otherwis', 'happi'): 1,
#    ('place', 'wast'): 1,
#    ('put', 'camera'): 1,
#    ('qualiti', 'superb'): 1,
#    ('real', 'mirror'): 1,
#    ('record', 'room'): 1,
#    ('room', 'start'): 1,
#    ('say', 'due'): 1,
#    ('side', 'i'): 1,
#    ('side', 'one'): 1,
#    ('side', 'otherwis'): 1,
#    ('side', 'side'): 2,
#    ('start', 'turn'): 1,
#    ('superb', 'fit'): 1,
#    ('toward', 'driver'): 1,
#    ('turn', 'toward'): 1,
#    ('video', 'qualiti'): 1,
#    ('wast', 'record'): 1,
#    ('wish', 'put'): 1},
#   'fake'),
#  ({('as', 'sling'): 1,
#    ('better', 'grip'): 1,
#    ('enough', 'purpos'): 1,
#    ('go', 'good'): 1,
#    ('good', 'enough'): 1,
#    ('handl', 'slimmer'): 1,
#    ('i', 'would'): 1,
#    ('prefer', 'handl'): 1,
#    ('purpos', 'though'): 1,
#    ('shot', 'go'): 1,
#    ('slimmer', 'better'): 1,
#    ('sling', 'shot'): 1,
#    ('though', 'i'): 1,
#    ('would', 'prefer'): 1},
#   'fake'),
#  ({('almost', 'week'): 1,
#    ('believ', 'great'): 1,
#    ('box', 'show'): 1,
#    ('br', 'br'): 1,
#    ('br', 'i'): 1,
#    ('br', 'price'): 1,
#    ('cut', 'differ'): 1,
#    ('differ', 'kind'): 1,
#    ('everi', 'box'): 1,
#    ('fair', 'realli'): 1,
#    ('fair', 'wish'): 1,
#    ('great', 'slicer'): 1,
#    ('help', 'br'): 1,
#    ('howev', 'took'): 1,
#    ('i', 'say'): 1,
#    ('idea', 'unfortun'): 1,
#    ('kind', 'veget'): 1,
#    ('learn', 'use'): 1,
#    ('manual', 'everi'): 1,
#    ('manual', 'someth'): 1,
#    ('may', 'say'): 1,
#    ('mean', 'manual'): 1,
#    ('negat', 'slicer'): 1,
#    ('price', 'may'): 1,
#    ('realli', 'believ'): 1,
#    ('say', 'fair'): 1,
#    ('say', 'someth'): 1,
#    ('show', 'us'): 1,
#    ('slicer', 'cut'): 1,
#    ('slicer', 'idea'): 1,
#    ('slicer', 'mean'): 1,
#    ('slicer', 'proper'): 1,
#    ('slicer', 'work'): 1,
#    ('someth', 'negat'): 1,
#    ('someth', 'would'): 1,
#    ('spiral', 'slicer'): 1,
#    ('took', 'almost'): 1,
#    ('tri', 'learn'): 1,
#    ('trick', 'use'): 1,
#    ('unfortun', 'trick'): 1,
#    ('us', 'use'): 1,
#    ('use', 'slicer'): 2,
#    ('use', 'spiral'): 1,
#    ('veget', 'br'): 1,
#    ('week', 'tri'): 1,
#    ('wish', 'manual'): 1,
#    ('work', 'howev'): 1,
#    ('would', 'help'): 1},
#   'fake'),
#  ({('adhes', 'br'): 1,
#    ('bought', 'stuff'): 1,
#    ('br', 'i'): 1,
#    ('dental', 'adhes'): 1,
#    ('especi', 'help'): 1,
#    ('father', 'satisfi'): 1,
#    ('help', 'use'): 1,
#    ('i', 'bought'): 1,
#    ('secur', 'dental'): 1,
#    ('stuff', 'father'): 1,
#    ('tablet', 'especi'): 1,
#    ('these', 'tablet'): 1,
#    ('use', 'secur'): 1},
#   'fake'),
#  ({('amazon', 'i'): 1,
#    ('cost', 'digit'): 1,
#    ('cost', 'paint'): 1,
#    ('decent', 'shown'): 1,
#    ('digit', 'print'): 1,
#    ('i', 'save'): 1,
#    ('look', 'decent'): 2,
#    ('paint', 'type'): 1,
#    ('photo', 'thank'): 1,
#    ('print', 'look'): 1,
#    ('save', 'cost'): 1,
#    ('shown', 'photo'): 1,
#    ('thank', 'you'): 1,
#    ('type', 'cost'): 1,
#    ('you', 'amazon'): 1},
#   'fake'),
#  ({('8', 'lbs'): 1,
#    ('appetit', 'i'): 1,
#    ('breakfast', 'lunch'): 1,
#    ('cut', 'appetit'): 1,
#    ('eat', 'much'): 1,
#    ('even', 'i'): 1,
#    ('find', 'older'): 1,
#    ('find', 'realli'): 1,
#    ('garcinia', 'month'): 1,
#    ('get', 'harder'): 1,
#    ('gotten', 'great'): 1,
#    ('great', 'result'): 1,
#    ('harder', 'lose'): 1,
#    ('i', 'find'): 2,
#    ('i', 'get'): 1,
#    ('i', 'gotten'): 1,
#    ('i', 'lost'): 2,
#    ('i', 'take'): 2,
#    ('i', 'tend'): 1,
#    ('late', 'even'): 1,
#    ('lbs', 'month'): 1,
#    ('long', 'time'): 1,
#    ('lose', 'weight'): 1,
#    ('lost', '8'): 1,
#    ('lost', 'long'): 1,
#    ('lunch', 'supper'): 1,
#    ('month', 'i'): 1,
#    ('month', 'way'): 1,
#    ('much', 'late'): 1,
#    ('older', 'i'): 1,
#    ('one', 'supper'): 1,
#    ('realli', 'cut'): 1,
#    ('result', 'take'): 1,
#    ('supper', 'i'): 2,
#    ('take', 'breakfast'): 1,
#    ('take', 'garcinia'): 1,
#    ('take', 'one'): 1,
#    ('tend', 'eat'): 1,
#    ('way', 'i'): 1,
#    ('weight', 'i'): 1},
#   'fake'),
#  ({('2', 'week'): 1,
#    ('camera', '2'): 1,
#    ('easi', 'use'): 1,
#    ('great', 'easi'): 1,
#    ('i', 'camera'): 1,
#    ('i', 'love'): 1,
#    ('pictur', 'great'): 1,
#    ('the', 'pictur'): 1,
#    ('use', 'i'): 1,
#    ('week', 'the'): 1},
#   'fake'),
#  ({('appetit', 'pound'): 1,
#    ('buy', 'product'): 1,
#    ('dosag', 'week'): 1,
#    ('energi', 'loss'): 1,
#    ('extra', 'energi'): 1,
#    ('felt', 'noth'): 1,
#    ('high', 'recommend'): 1,
#    ('i', 'took'): 1,
#    ('it', 'high'): 1,
#    ('loss', 'appetit'): 1,
#    ('noth', 'extra'): 1,
#    ('pound', 'lost'): 1,
#    ('product', 'i'): 1,
#    ('recommend', 'buy'): 1,
#    ('suggest', 'dosag'): 1,
#    ('took', 'suggest'): 1,
#    ('week', 'felt'): 1},
#   'fake'),
#  ({('actual', 'power'): 1,
#    ('apart', 'orient'): 1,
#    ('avoid', 'bird'): 1,
#    ('backward', 'wire'): 1,
#    ('bird', 'nest'): 1,
#    ('cabl', 'har'): 1,
#    ('complet', 'taken'): 1,
#    ('good', 'cabl'): 1,
#    ('har', 'complet'): 1,
#    ('it', 'like'): 1,
#    ('like', 'test'): 1,
#    ('nest', 'backward'): 1,
#    ('orient', 'avoid'): 1,
#    ('power', 'suppli'): 1,
#    ('see', 'work'): 1,
#    ('suppli', 'good'): 1,
#    ('taken', 'apart'): 1,
#    ('test', 'see'): 1,
#    ('the', 'actual'): 1,
#    ('tower', 'it'): 1,
#    ('wire', 'tower'): 1},
#   'fake'),
#  ({('10', 'free'): 1,
#    ('129', 'the'): 1,
#    ('18', 'current'): 1,
#    ('2', 'bottl'): 1,
#    ('20', 'time'): 1,
#    ('200', '129'): 1,
#    ('3', '20'): 1,
#    ('absorb', 'capac'): 1,
#    ('ach', 'i'): 1,
#    ('acid', 'it'): 1,
#    ('almost', 'instant'): 1,
#    ('also', 'use'): 1,
#    ('anoth', 'time'): 1,
#    ('anti', 'biotic'): 2,
#    ('anti', 'oxid'): 2,
#    ('antioxid', 'capac'): 1,
#    ('anywher', '3'): 1,
#    ('bacteria', 'virus'): 1,
#    ('benifit', 'oregano'): 1,
#    ('best', 'work'): 1,
#    ('better', '18'): 1,
#    ('biotic', 'ever'): 1,
#    ('biotic', 'treatment'): 1,
#    ('bodi', 'ach'): 1,
#    ('bottl', 'oreganol'): 1,
#    ('bought', 'goo'): 1,
#    ('br', 'br'): 2,
#    ('br', 'i'): 1,
#    ('br', 'you'): 1,
#    ('capac', 'anywher'): 1,
#    ('capac', 'orac'): 1,
#    ('complet', 'elimin'): 1,
#    ('contamin', 'food'): 1,
#    ('coupl', 'drop'): 1,
#    ('current', 'use'): 1,
#    ('destroy', 'pathogen'): 1,
#    ('digest', 'distress'): 1,
#    ('discomfort', 'dryness'): 1,
#    ('distress', 'eat'): 1,
#    ('drank', 'this'): 1,
#    ('drop', 'oil'): 1,
#    ('dryness', 'throat'): 1,
#    ('eat', 'i'): 1,
#    ('elimin', 'digest'): 1,
#    ('emerg', 'medicin'): 1,
#    ('enorm', 'benifit'): 1,
#    ('ever', 'studi'): 1,
#    ('fantast', 'i'): 1,
#    ('feel', 'great'): 1,
#    ('felt', 'bodi'): 1,
#    ('felt', 'great'): 1,
#    ('flavonoid', 'phenol'): 1,
#    ('found', 'contamin'): 1,
#    ('found', 'recent'): 1,
#    ('free', 'felt'): 1,
#    ('free', 'sampl'): 1,
#    ('fridg', 'wowww'): 1,
#    ('gl', 'wa7ai'): 1,
#    ('goo', 'gl'): 1,
#    ('great', 'anoth'): 1,
#    ('great', 'second'): 1,
#    ('great', 'stuff'): 1,
#    ('heal', 'herb'): 1,
#    ('heal', 'sooth'): 1,
#    ('herb', 'br'): 1,
#    ('herb', 'natur'): 1,
#    ('herb', 'oxygen'): 1,
#    ('herb', 'rich'): 1,
#    ('higher', 'herb'): 1,
#    ('highest', 'herb'): 1,
#    ('i', 'also'): 1,
#    ('i', 'bought'): 1,
#    ('i', 'discomfort'): 1,
#    ('i', 'felt'): 1,
#    ('i', 'found'): 1,
#    ('i', 'told'): 1,
#    ('i', 'took'): 2,
#    ('impress', 'score'): 1,
#    ('infect', 'the'): 1,
#    ('instant', 'feel'): 1,
#    ('it', 'found'): 1,
#    ('it', 'third'): 1,
#    ('medicin', 'complet'): 1,
#    ('miracul', 'i'): 1,
#    ('mrsa', 'staph'): 1,
#    ('my', 'person'): 1,
#    ('natur', 'anti'): 1,
#    ('oil', 'best'): 1,
#    ('oil', 'fantast'): 1,
#    ('oil', 'heal'): 1,
#    ('oil', 'tablespoon'): 1,
#    ('oil', 'way'): 1,
#    ('one', 'power'): 1,
#    ('orac', 'impress'): 1,
#    ('oregano', 'antioxid'): 1,
#    ('oregano', 'emerg'): 1,
#    ('oregano', 'oil'): 1,
#    ('oregano', 'one'): 1,
#    ('oreganol', 'p73'): 1,
#    ('oxid', 'destroy'): 1,
#    ('oxid', 'phytochem'): 1,
#    ('oxygen', 'radic'): 1,
#    ('p73', 'fridg'): 1,
#    ('pathogen', 'bacteria'): 1,
#    ('person', 'physician'): 1,
#    ('phenol', 'acid'): 1,
#    ('phenol', 'anti'): 1,
#    ('physician', 'recommend'): 1,
#    ('phytochem', 'flavonoid'): 1,
#    ('power', 'heal'): 1,
#    ('radic', 'absorb'): 1,
#    ('rank', 'oregano'): 1,
#    ('recent', 'studi'): 1,
#    ('recommend', 'i'): 1,
#    ('rich', 'anti'): 1,
#    ('sampl', 'great'): 1,
#    ('score', '200'): 1,
#    ('second', 'this'): 1,
#    ('see', '2'): 1,
#    ('set', 'free'): 1,
#    ('signific', 'better'): 1,
#    ('sooth', 'throat'): 1,
#    ('staph', 'infect'): 1,
#    ('strong', 'phenol'): 1,
#    ('studi', 'it'): 1,
#    ('studi', 'signific'): 1,
#    ('stuff', 'br'): 1,
#    ('super', 'herb'): 1,
#    ('tablespoon', 'water'): 1,
#    ('the', 'strong'): 1,
#    ('the', 'usda'): 1,
#    ('third', 'highest'): 1,
#    ('this', 'oil'): 2,
#    ('this', 'super'): 1,
#    ('throat', 'almost'): 1,
#    ('throat', 'i'): 1,
#    ('time', 'higher'): 1,
#    ('time', 'i'): 1,
#    ('told', 'enorm'): 1,
#    ('took', 'coupl'): 1,
#    ('took', 'oil'): 1,
#    ('treatment', 'mrsa'): 1,
#    ('usda', 'rank'): 1,
#    ('use', 'anti'): 1,
#    ('use', 'oregano'): 1,
#    ('virus', 'yeast'): 1,
#    ('wa7ai', '10'): 1,
#    ('water', 'drank'): 1,
#    ('way', 'set'): 1,
#    ('work', 'miracul'): 1,
#    ('wowww', 'oregano'): 1,
#    ('yeast', 'this'): 1,
#    ('you', 'see'): 1},
#   'fake'),
#  ({('color', 'cup'): 1,
#    ('easili', 'read'): 1,
#    ('eye', 'use'): 1,
#    ('fact', 'easili'): 1,
#    ('get', 'tire'): 1,
#    ('great', 'us'): 1,
#    ('i', 'get'): 1,
#    ('i', 'love'): 1,
#    ('lol', 'i'): 1,
#    ('love', 'fact'): 1,
#    ('measur', 'great'): 1,
#    ('number', 'other'): 1,
#    ('other', 'color'): 1,
#    ('read', 'measur'): 1,
#    ('read', 'number'): 1,
#    ('tire', 'tri'): 1,
#    ('tri', 'read'): 1,
#    ('us', 'eye'): 1,
#    ('use', 'lol'): 1},
#   'fake'),
#  ({('anoth', 'i'): 1,
#    ('bought', 'sever'): 1,
#    ('coffe', 'exact'): 1,
#    ('exact', 'say'): 1,
#    ('finish', 'bottl'): 1,
#    ('green', 'coffe'): 1,
#    ('happi', 'purchas'): 1,
#    ('i', 'bought'): 1,
#    ('i', 'finish'): 1,
#    ('i', 'happi'): 1,
#    ('i', 'pleas'): 1,
#    ('pleas', 'the'): 1,
#    ('product', 'seller'): 1,
#    ('purchas', 'anoth'): 1,
#    ('say', 'i'): 1,
#    ('seller', 'i'): 1,
#    ('sever', 'product'): 1,
#    ('the', 'green'): 1},
#   'fake'),
#  ({('2', 'one'): 1,
#    ('50', 'one'): 1,
#    ('back', 'howev'): 1,
#    ('back', 'you'): 1,
#    ('blanket', 'we'): 1,
#    ('cannot', 'feel'): 1,
#    ('electr', 'blanket'): 1,
#    ('extrem', 'well'): 1,
#    ('feel', 'quit'): 1,
#    ('feel', 'wire'): 1,
#    ('howev', 'said'): 1,
#    ('i', 'feel'): 1,
#    ('indic', 'last'): 1,
#    ('last', 'year'): 1,
#    ('luxuri', 'i'): 1,
#    ('made', 'electr'): 1,
#    ('materi', 'luxuri'): 1,
#    ('one', 'took'): 2,
#    ('pricey', '50'): 1,
#    ('qualiti', 'indic'): 1,
#    ('quit', 'pricey'): 1,
#    ('said', 'qualiti'): 1,
#    ('this', 'extrem'): 1,
#    ('took', 'back'): 2,
#    ('tri', '2'): 1,
#    ('we', 'tri'): 1,
#    ('well', 'made'): 1,
#    ('wire', 'materi'): 1,
#    ('you', 'cannot'): 1},
#   'fake'),
#  ({('coffe', 'love'): 1,
#    ('coffe', 'lover'): 1,
#    ('easi', 'clean'): 1,
#    ('flavor', 'coffe'): 1,
#    ('great', 'product'): 1,
#    ('littl', 'rich'): 1,
#    ('love', 'easi'): 1,
#    ('lover', 'want'): 1,
#    ('product', 'coffe'): 1,
#    ('rich', 'flavor'): 1,
#    ('want', 'littl'): 1},
#   'fake'),
#  ({('abl', 'use'): 1,
#    ('bottl', 'i'): 1,
#    ('bottl', 'though'): 1,
#    ('cheap', 'water'): 1,
#    ('dasani', 'bottl'): 1,
#    ('figur', 'would'): 1,
#    ('fit', 'dasani'): 1,
#    ('i', 'abl'): 1,
#    ('i', 'figur'): 1,
#    ('sure', 'fit'): 1,
#    ('use', 'cheap'): 1,
#    ('water', 'bottl'): 1,
#    ('would', 'sure'): 1},
#   'fake'),
#  ({('acquir', 'particular'): 1,
#    ('aesthet', 'it'): 1,
#    ('allow', 'set'): 1,
#    ('alreadi', 'own'): 1,
#    ('beauti', 'white'): 1,
#    ('befor', 'acquir'): 1,
#    ('color', 'scheme'): 1,
#    ('decor', 'beauti'): 1,
#    ('dinnerwar', 'set'): 4,
#    ('goe', 'color'): 1,
#    ('i', 'alreadi'): 1,
#    ('it', 'allow'): 1,
#    ('much', 'nicer'): 1,
#    ('nice', 'aesthet'): 1,
#    ('own', 'plain'): 1,
#    ('particular', 'dinnerwar'): 1,
#    ('plain', 'white'): 1,
#    ('platinum', 'rim'): 1,
#    ('provid', 'nice'): 1,
#    ('rim', 'much'): 1,
#    ('scheme', 'befor'): 1,
#    ('set', 'dinnerwar'): 1,
#    ('set', 'goe'): 1,
#    ('set', 'i'): 1,
#    ('set', 'platinum'): 1,
#    ('set', 'provid'): 1,
#    ('set', 'tabl'): 1,
#    ('tabl', 'decor'): 1,
#    ('this', 'dinnerwar'): 1,
#    ('white', 'dinnerwar'): 1,
#    ('white', 'set'): 1},
#   'fake'),
#  ({('becam', 'blackish'): 1,
#    ('blackish', 'part'): 1,
#    ('case', 'match'): 1,
#    ('color', 'becam'): 1,
#    ('issu', 'tan'): 1,
#    ('look', 'unpleas'): 1,
#    ('match', 'phone'): 1,
#    ('part', 'look'): 1,
#    ('phone', 'real'): 1,
#    ('real', 'issu'): 1,
#    ('side', 'case'): 1,
#    ('tan', 'color'): 1,
#    ('the', 'side'): 1,
#    ('unpleas', 'use'): 1,
#    ('use', 'like'): 1},
#   'fake'),
#  ({('bubbl', 'wrap'): 1,
#    ('color', 'littl'): 1,
#    ('custom', 'servic'): 1,
#    ('cute', 'mine'): 1,
#    ('especi', 'wear'): 1,
#    ('face', 'i'): 1,
#    ('facial', 'hair'): 1,
#    ('foundat', 'the'): 1,
#    ('fuzz', 'especi'): 1,
#    ('got', 'smash'): 1,
#    ('great', 'custom'): 1,
#    ('hair', 'face'): 1,
#    ('hair', 'remov'): 1,
#    ('hard', 'use'): 1,
#    ('hate', 'peach'): 1,
#    ('hurt', 'much'): 1,
#    ('i', 'hate'): 1,
#    ('i', 'love'): 1,
#    ('i', 'low'): 1,
#    ('it', 'take'): 1,
#    ('littl', 'hard'): 1,
#    ('lot', 'hair'): 1,
#    ('love', 'color'): 1,
#    ('love', 'i'): 1,
#    ('low', 'pain'): 1,
#    ('mine', 'got'): 1,
#    ('much', 'it'): 1,
#    ('okay', 'love'): 1,
#    ('packag', 'bubbl'): 1,
#    ('pain', 'toler'): 1,
#    ('peach', 'fuzz'): 1,
#    ('process', 'ship'): 1,
#    ('remov', 'hurt'): 1,
#    ('ship', 'great'): 1,
#    ('sinc', 'i'): 1,
#    ('smash', 'process'): 1,
#    ('take', 'lot'): 1,
#    ('the', 'tweezer'): 1,
#    ('toler', 'facial'): 1,
#    ('tweezer', 'okay'): 1,
#    ('use', 'wish'): 1,
#    ('wear', 'foundat'): 1,
#    ('wish', 'packag'): 1,
#    ('wrap', 'cute'): 1},
#   'fake'),
#  ({('accommod', 'd3100'): 1,
#    ('along', 'batteri'): 1,
#    ('bag', 'look'): 1,
#    ('batteri', 'charger'): 1,
#    ('d3100', 'two'): 1,
#    ('describ', 'much'): 1,
#    ('found', 'hard'): 1,
#    ('hard', 'accommod'): 1,
#    ('hold', 'i'): 1,
#    ('i', 'found'): 1,
#    ('lens', 'along'): 1,
#    ('like', 'littl'): 1,
#    ('littl', 'smaller'): 1,
#    ('look', 'like'): 1,
#    ('lot', 'describ'): 1,
#    ('much', 'hold'): 1,
#    ('one', 'pictur'): 1,
#    ('pictur', 'show'): 1,
#    ('pictur', 'the'): 1,
#    ('show', 'lot'): 1,
#    ('smaller', 'version'): 1,
#    ('the', 'bag'): 1,
#    ('the', 'pictur'): 1,
#    ('two', 'lens'): 1,
#    ('version', 'one'): 1},
#   'fake'),
#  ({('appli', 'clean'): 1,
#    ('bought', 'use'): 1,
#    ('easi', 'appli'): 1,
#    ('eyelin', 'the'): 1,
#    ('gel', 'eyelin'): 1,
#    ('handl', 'longer'): 1,
#    ('i', 'like'): 2,
#    ('like', 'slant'): 1,
#    ('like', 'work'): 1,
#    ('longer', 'i'): 1,
#    ('slant', 'easi'): 1,
#    ('the', 'handl'): 1,
#    ('use', 'gel'): 1,
#    ('well', 'i'): 1,
#    ('work', 'well'): 1},
#   'fake'),
#  ({('34', 'cup'): 1,
#    ('34', 'doesnt'): 1,
#    ('4am', 'go'): 1,
#    ('5', 'star'): 1,
#    ('back', 'make'): 1,
#    ('bra', 'like'): 1,
#    ('butthead', 'turn'): 1,
#    ('cup', '34'): 1,
#    ('didnt', 'give'): 1,
#    ('doesnt', 'touch'): 1,
#    ('eye', 'this'): 1,
#    ('eyelid', 'nice'): 1,
#    ('flat', 'eye'): 1,
#    ('flat', 'sleep'): 1,
#    ('for', 'i'): 1,
#    ('get', '4am'): 1,
#    ('get', 'ive'): 1,
#    ('give', '5'): 1,
#    ('go', 'work'): 1,
#    ('great', 'purpos'): 1,
#    ('hate', 'sleep'): 1,
#    ('havent', 'issu'): 1,
#    ('hub', 'get'): 1,
#    ('i', 'didnt'): 1,
#    ('i', 'hate'): 1,
#    ('i', 'sleep'): 1,
#    ('i', 'turn'): 1,
#    ('issu', 'sleep'): 1,
#    ('it', 'look'): 1,
#    ('itchi', 'the'): 1,
#    ('ive', 'havent'): 1,
#    ('keep', 'light'): 1,
#    ('kinda', 'made'): 1,
#    ('lay', 'flat'): 1,
#    ('light', 'sinc'): 1,
#    ('light', 'sure'): 1,
#    ('like', 'mini'): 1,
#    ('like', 'tradit'): 1,
#    ('littl', '34'): 1,
#    ('lol', 'it'): 1,
#    ('look', 'like'): 1,
#    ('made', 'itchi'): 1,
#    ('made', 'uncomfort'): 1,
#    ('make', 'stay'): 1,
#    ('mask', 'great'): 1,
#    ('mask', 'lay'): 1,
#    ('mask', 'made'): 1,
#    ('mini', 'bra'): 1,
#    ('my', 'hub'): 1,
#    ('nice', 'old'): 1,
#    ('old', 'sleep'): 1,
#    ('one', 'littl'): 1,
#    ('purpos', 'keep'): 1,
#    ('reason', 'i'): 1,
#    ('side', 'kinda'): 1,
#    ('sinc', 'get'): 1,
#    ('sleep', 'back'): 2,
#    ('sleep', 'i'): 1,
#    ('sleep', 'lol'): 1,
#    ('sleep', 'mask'): 2,
#    ('sleep', 'side'): 1,
#    ('star', 'whenev'): 1,
#    ('stay', 'for'): 1,
#    ('sure', 'my'): 1,
#    ('the', 'reason'): 1,
#    ('this', 'mask'): 1,
#    ('this', 'one'): 1,
#    ('touch', 'eyelid'): 1,
#    ('tradit', 'flat'): 1,
#    ('turn', 'light'): 1,
#    ('turn', 'sleep'): 1,
#    ('uncomfort', 'sleep'): 1,
#    ('whenev', 'i'): 1,
#    ('work', 'butthead'): 1},
#   'fake'),
#  ({('built', 'qualiti'): 1,
#    ('cool', 'nice'): 1,
#    ('i', 'use'): 1,
#    ('it', 'realli'): 1,
#    ('last', 'month'): 1,
#    ('look', 'realli'): 1,
#    ('month', 'it'): 1,
#    ('nice', 'built'): 1,
#    ('photoshoot', 'last'): 1,
#    ('qualiti', 'vintag'): 1,
#    ('realli', 'awesom'): 1,
#    ('realli', 'cool'): 1,
#    ('use', 'photoshoot'): 1,
#    ('vintag', 'look'): 1},
#   'fake'),
#  ({('10', 'free'): 1,
#    ('150', 'amaz'): 1,
#    ('220', '150'): 1,
#    ('32eeb', 'fabul'): 1,
#    ('45', 'revascular'): 1,
#    ('5', 'cent'): 1,
#    ('5zi8i', '600mg'): 1,
#    ('600mg', 'tablet'): 1,
#    ('a', 'clinic'): 1,
#    ('a', 'recent'): 1,
#    ('addit', '10'): 1,
#    ('angioplasti', 'cardiovascular'): 1,
#    ('attack', '45'): 1,
#    ('attack', 'found'): 1,
#    ('balanc', 'cholesterol'): 1,
#    ('benefici', 'supplement'): 1,
#    ('best', 'nattokinas'): 1,
#    ('biochem', 'pharmacolog'): 1,
#    ('bodi', 'studi'): 1,
#    ('bought', 'goo'): 1,
#    ('br', 'a'): 1,
#    ('br', 'br'): 2,
#    ('br', 'recent'): 1,
#    ('bypass', 'surgeri'): 1,
#    ('cancer', 'mortal'): 1,
#    ('cardiovascular', 'mortal'): 1,
#    ('cent', 'addit'): 1,
#    ('cholesterol', '220'): 1,
#    ('cholesterol', 'i'): 1,
#    ('cholesterol', 'relat'): 1,
#    ('clinic', 'studi'): 1,
#    ('combin', 'red'): 1,
#    ('extract', 'red'): 1,
#    ('fabul', 'job'): 1,
#    ('found', 'nattokinas'): 1,
#    ('found', 'partial'): 1,
#    ('free', 'sampl'): 1,
#    ('gl', '32eeb'): 1,
#    ('gl', '5zi8i'): 1,
#    ('goo', 'gl'): 2,
#    ('great', 'stuff'): 1,
#    ('hdl', 'a'): 1,
#    ('healthi', 'balanc'): 1,
#    ('heart', 'attack'): 2,
#    ('i', 'bought'): 1,
#    ('i', 'use'): 1,
#    ('identifi', 'red'): 1,
#    ('increas', 'hdl'): 1,
#    ('job', 'reduc'): 1,
#    ('ldl', 'overal'): 1,
#    ('ldl', 'triglycerid'): 1,
#    ('lipid', 'bodi'): 1,
#    ('lower', 'cholesterol'): 1,
#    ('lower', 'ldl'): 1,
#    ('maintain', 'healthi'): 1,
#    ('mortal', 'one'): 1,
#    ('mortal', 'total'): 1,
#    ('mortal', 'two'): 1,
#    ('my', 'person'): 1,
#    ('nattokinas', 'combin'): 1,
#    ('nattokinas', 'goo'): 1,
#    ('one', 'third'): 1,
#    ('overal', 'cholesterol'): 1,
#    ('partial', 'purifi'): 1,
#    ('patient', 'suffer'): 1,
#    ('person', 'physician'): 1,
#    ('pharmacolog', 'studi'): 1,
#    ('physician', 'recommend'): 1,
#    ('purifi', 'extract'): 1,
#    ('recent', 'biochem'): 1,
#    ('recent', 'studi'): 1,
#    ('recommend', 'i'): 1,
#    ('red', 'yeast'): 3,
#    ('reduc', 'ldl'): 1,
#    ('reduc', 'risk'): 1,
#    ('relat', 'lipid'): 1,
#    ('repeat', 'heart'): 1,
#    ('report', 'lower'): 1,
#    ('revascular', 'bypass'): 1,
#    ('rice', 'benefici'): 1,
#    ('rice', 'reduc'): 1,
#    ('rice', 'signific'): 1,
#    ('risk', 'repeat'): 1,
#    ('sampl', 'great'): 1,
#    ('signific', 'lower'): 1,
#    ('studi', 'found'): 1,
#    ('studi', 'identifi'): 1,
#    ('studi', 'patient'): 1,
#    ('studi', 'report'): 1,
#    ('stuff', 'br'): 1,
#    ('suffer', 'heart'): 1,
#    ('supplement', 'maintain'): 1,
#    ('surgeri', 'angioplasti'): 1,
#    ('tablet', '5'): 1,
#    ('third', 'br'): 1,
#    ('third', 'cancer'): 1,
#    ('total', 'mortal'): 1,
#    ('triglycerid', 'increas'): 1,
#    ('two', 'third'): 1,
#    ('use', 'best'): 1,
#    ('yeast', 'rice'): 3},
#   'fake'),
#  ({('1', 'star'): 1,
#    ('all', 'review'): 1,
#    ('anyon', 'realli'): 1,
#    ('away', 'look'): 1,
#    ('blood', 'stool'): 2,
#    ('buyer', 'ware'): 1,
#    ('fake', 'buyer'): 1,
#    ('go', 'all'): 1,
#    ('got', 'blood'): 1,
#    ('i', 'got'): 1,
#    ('i', 'took'): 1,
#    ('if', 'anyon'): 1,
#    ('look', 'review'): 1,
#    ('no', 'go'): 1,
#    ('one', 'want'): 1,
#    ('posit', 'thing'): 1,
#    ('realli', 'took'): 1,
#    ('review', 'fake'): 1,
#    ('review', 'if'): 1,
#    ('review', 'one'): 1,
#    ('review', 'posit'): 1,
#    ('right', 'away'): 1,
#    ('same', 'review'): 1,
#    ('say', 'same'): 1,
#    ('star', 'review'): 1,
#    ('stool', 'stop'): 1,
#    ('stop', 'take'): 1,
#    ('take', 'right'): 1,
#    ('thing', 'say'): 1,
#    ('took', 'i'): 1,
#    ('took', 'would'): 1,
#    ('want', 'blood'): 1,
#    ('ware', 'i'): 1,
#    ('would', 'write'): 1,
#    ('write', '1'): 1},
#   'fake'),
#  ({('1', 'hair'): 1,
#    ('10', 'free'): 1,
#    ('2', 'diabet'): 1,
#    ('2', 'month'): 1,
#    ('2', 'treatment'): 1,
#    ('3', 'fat'): 1,
#    ('3', 'month'): 2,
#    ('4', 'reduc'): 1,
#    ('5', 'gene'): 1,
#    ('5hndv', '10'): 1,
#    ('6', 'blood'): 1,
#    ('abl', 'prevent'): 1,
#    ('after', 'use'): 1,
#    ('alopecia', 'peopl'): 1,
#    ('also', 'help'): 1,
#    ('also', 'use'): 1,
#    ('biotin', '3'): 1,
#    ('biotin', 'also'): 2,
#    ('biotin', 'help'): 3,
#    ('biotin', 'integr'): 1,
#    ('biotin', 'often'): 1,
#    ('biotin', 'role'): 1,
#    ('biotin', 'said'): 1,
#    ('biotin', 'treat'): 1,
#    ('blood', 'cell'): 2,
#    ('blood', 'sugar'): 2,
#    ('bone', 'marrow'): 2,
#    ('bought', 'goo'): 1,
#    ('br', '1'): 1,
#    ('br', '2'): 1,
#    ('br', '3'): 1,
#    ('br', '4'): 1,
#    ('br', '5'): 1,
#    ('br', '6'): 1,
#    ('br', 'br'): 2,
#    ('br', 'my'): 2,
#    ('brittl', 'toe'): 1,
#    ('burner', 'biotin'): 1,
#    ('burner', 'one'): 1,
#    ('candida', 'said'): 1,
#    ('candida', 'some'): 1,
#    ('carb', 'br'): 1,
#    ('case', 'doctor'): 1,
#    ('cell', 'bone'): 2,
#    ('chang', 'fungal'): 1,
#    ('combat', 'gray'): 1,
#    ('decid', 'tri'): 1,
#    ('deeper', 'level'): 1,
#    ('diabet', 'reduc'): 1,
#    ('differ', 'purpos'): 1,
#    ('doctor', 'recommend'): 1,
#    ('due', 'low'): 1,
#    ('facet', 'vitamin'): 1,
#    ('fat', 'burner'): 2,
#    ('fat', 'protein'): 1,
#    ('fingernail', 'biotin'): 1,
#    ('form', 'br'): 1,
#    ('free', 'sampl'): 1,
#    ('fungal', 'form'): 1,
#    ('gene', 'replic'): 2,
#    ('get', 'trim'): 1,
#    ('gl', '5hndv'): 1,
#    ('goo', 'gl'): 1,
#    ('good', 'skin'): 1,
#    ('gotten', 'point'): 1,
#    ('gray', 'hair'): 2,
#    ('great', 'stuff'): 1,
#    ('grow', 'healthi'): 1,
#    ('grown', 'level'): 1,
#    ('growth', 'length'): 1,
#    ('hair', 'br'): 1,
#    ('hair', 'due'): 1,
#    ('hair', 'good'): 1,
#    ('hair', 'i'): 1,
#    ('hair', 'loss'): 1,
#    ('hair', 'skin'): 1,
#    ('hair', 'thin'): 1,
#    ('haircut', 'grown'): 1,
#    ('hairdress', 'surpris'): 1,
#    ('happi', 'report'): 1,
#    ('healthi', 'blood'): 1,
#    ('healthi', 'hair'): 1,
#    ('help', 'combat'): 1,
#    ('help', 'grow'): 1,
#    ('help', 'metabol'): 1,
#    ('help', 'peopl'): 1,
#    ('help', 'product'): 1,
#    ('help', 'treat'): 1,
#    ('i', 'bought'): 1,
#    ('i', 'decid'): 1,
#    ('i', 'happi'): 1,
#    ('i', 'seen'): 1,
#    ('i', 'success'): 1,
#    ('i', 'went'): 1,
#    ('in', 'case'): 1,
#    ('integr', 'gene'): 1,
#    ('it', 'gotten'): 1,
#    ('it', 'much'): 1,
#    ('job', 'it'): 1,
#    ('last', 'haircut'): 1,
#    ('least', 'reach'): 1,
#    ('length', 'much'): 1,
#    ('level', 'biotin'): 2,
#    ('level', 'would'): 1,
#    ('loss', 'alopecia'): 1,
#    ('low', 'level'): 1,
#    ('make', 'ponytail'): 1,
#    ('manag', 'it'): 1,
#    ('marrow', 'biotin'): 1,
#    ('marrow', 'br'): 1,
#    ('metabol', 'fat'): 1,
#    ('month', 'i'): 1,
#    ('month', 'last'): 1,
#    ('month', 'least'): 1,
#    ('much', 'growth'): 1,
#    ('much', 'hairdress'): 1,
#    ('much', 'thicker'): 1,
#    ('multi', 'facet'): 1,
#    ('my', 'hair'): 1,
#    ('my', 'person'): 2,
#    ('nail', 'biotin'): 1,
#    ('normal', 'taken'): 1,
#    ('number', 'differ'): 1,
#    ('often', 'promot'): 1,
#    ('on', 'deeper'): 1,
#    ('one', 'principl'): 1,
#    ('peopl', 'prematur'): 1,
#    ('peopl', 'type'): 1,
#    ('peopl', 'use'): 1,
#    ('person', 'physician'): 2,
#    ('physician', 'recommend'): 1,
#    ('physician', 'told'): 1,
#    ('point', 'i'): 1,
#    ('ponytail', 'i'): 1,
#    ('prematur', 'gray'): 1,
#    ('prettier', 'manag'): 1,
#    ('prevent', 'yeast'): 1,
#    ('principl', 'role'): 1,
#    ('product', 'healthi'): 1,
#    ('promot', 'fat'): 1,
#    ('protein', 'carb'): 1,
#    ('purpos', 'br'): 1,
#    ('recommend', 'biotin'): 1,
#    ('recommend', 'i'): 1,
#    ('reduc', 'blood'): 2,
#    ('replic', 'br'): 1,
#    ('replic', 'on'): 1,
#    ('report', 'stronger'): 1,
#    ('role', 'biotin'): 1,
#    ('role', 'multi'): 1,
#    ('said', 'abl'): 1,
#    ('said', 'help'): 1,
#    ('sampl', 'great'): 1,
#    ('seen', 'much'): 1,
#    ('skin', 'nail'): 1,
#    ('skin', 'use'): 1,
#    ('some', 'peopl'): 1,
#    ('stress', 'job'): 1,
#    ('stronger', 'thicker'): 1,
#    ('stuff', 'br'): 1,
#    ('success', 'make'): 1,
#    ('sugar', 'br'): 1,
#    ('sugar', 'in'): 1,
#    ('surpris', 'when'): 1,
#    ('taken', '3'): 1,
#    ('thicker', 'hair'): 1,
#    ('thicker', 'prettier'): 1,
#    ('thin', 'work'): 1,
#    ('toe', 'fingernail'): 1,
#    ('told', 'biotin'): 1,
#    ('treat', 'brittl'): 1,
#    ('treat', 'candida'): 1,
#    ('treat', 'hair'): 1,
#    ('treatment', 'candida'): 1,
#    ('tri', 'after'): 1,
#    ('trim', '2'): 1,
#    ('type', '2'): 1,
#    ('use', 'biotin'): 2,
#    ('use', 'help'): 1,
#    ('use', 'number'): 1,
#    ('use', 'treat'): 1,
#    ('vitamin', 'use'): 1,
#    ('went', 'get'): 1,
#    ('when', 'i'): 1,
#    ('work', 'stress'): 1,
#    ('would', 'normal'): 1,
#    ('yeast', 'chang'): 1},
#   'fake'),
#  ({('burn', 'fat'): 1,
#    ('but', 'take'): 1,
#    ('calcium', 'hamper'): 1,
#    ('care', 'contain'): 1,
#    ('contain', 'long'): 1,
#    ('dont', 'realli'): 1,
#    ('fat', 'but'): 1,
#    ('fit', 'go'): 1,
#    ('hamper', 'burn'): 1,
#    ('i', 'lose'): 1,
#    ('keep', 'fit'): 1,
#    ('lbs', 'so'): 1,
#    ('long', 'keep'): 1,
#    ('lose', 'lbs'): 1,
#    ('mani', 'review'): 1,
#    ('octob', 'i'): 1,
#    ('read', 'mani'): 1,
#    ('realli', 'care'): 1,
#    ('review', 'calcium'): 1,
#    ('sinc', 'octob'): 1,
#    ('so', 'dont'): 1,
#    ('take', 'sinc'): 1},
#   'fake'),
#  ({('3', 'spare'): 1,
#    ('although', 'still'): 1,
#    ('cheap', 'it'): 1,
#    ('durabl', 'length'): 1,
#    ('expect', 'cheap'): 1,
#    ('it', 'lightweight'): 1,
#    ('know', 'use'): 1,
#    ('length', 'perfect'): 1,
#    ('lightweight', 'durabl'): 1,
#    ('pen', 'know'): 1,
#    ('perfect', 'wife'): 1,
#    ('spare', 'stylus'): 1,
#    ('still', '3'): 1,
#    ('stylus', 'pen'): 1,
#    ('wife', 'although'): 1,
#    ('work', 'expect'): 1},
#   'fake'),
#  ({('1', 'asthma'): 1,
#    ('10', 'free'): 1,
#    ('10', 'high'): 1,
#    ('11', 'male'): 1,
#    ('12', 'heart'): 1,
#    ('13', 'leg'): 1,
#    ('14', 'pregnanc'): 1,
#    ('15', 'pain'): 1,
#    ('16', 'pycnogenol'): 1,
#    ('2', 'chronic'): 1,
#    ('2', 'diabet'): 1,
#    ('3', 'varicos'): 1,
#    ('4', 'high'): 1,
#    ('5', 'retinopathi'): 1,
#    ('50', 'diseas'): 1,
#    ('6', 'attent'): 1,
#    ('7', 'blood'): 1,
#    ('8', 'diabet'): 1,
#    ('9', 'impot'): 1,
#    ('ad', 'regimen'): 1,
#    ('add', 'prevent'): 1,
#    ('adhd', 'br'): 1,
#    ('allergi', 'asthma'): 1,
#    ('allergi', 'cough'): 1,
#    ('also', 'hope'): 1,
#    ('also', 'known'): 1,
#    ('also', 'provid'): 1,
#    ('also', 'said'): 1,
#    ('ask', 'but'): 1,
#    ('associ', 'effect'): 1,
#    ('asthma', 'br'): 1,
#    ('asthma', 'neither'): 1,
#    ('at', 'begin'): 1,
#    ('athlet', 'perform'): 1,
#    ('attack', 'stroke'): 1,
#    ('attent', 'deficit'): 1,
#    ('away', 'complet'): 1,
#    ('back', 'pain'): 1,
#    ('back', 'see'): 1,
#    ('bad', 'cold'): 1,
#    ('bark', 'benefici'): 1,
#    ('begin', 'januari'): 1,
#    ('benefici', 'effect'): 1,
#    ('benefit', 'soon'): 1,
#    ('blood', 'clot'): 1,
#    ('blood', 'pressur'): 1,
#    ('bought', 'goo'): 1,
#    ('br', '1'): 1,
#    ('br', '10'): 1,
#    ('br', '11'): 1,
#    ('br', '12'): 1,
#    ('br', '13'): 1,
#    ('br', '14'): 1,
#    ('br', '15'): 1,
#    ('br', '16'): 1,
#    ('br', '2'): 1,
#    ('br', '4'): 1,
#    ('br', '5'): 1,
#    ('br', '6'): 1,
#    ('br', '7'): 1,
#    ('br', '8'): 1,
#    ('br', '9'): 1,
#    ('br', 'br'): 2,
#    ('br', 'he'): 1,
#    ('br', 'so'): 1,
#    ('but', 'whatev'): 1,
#    ('cant', 'heal'): 1,
#    ('cap', 'time'): 1,
#    ('caus', 'diabet'): 1,
#    ('chang', 'br'): 1,
#    ('cholesterol', 'br'): 1,
#    ('chronic', 'venous'): 1,
#    ('circulatori', 'longev'): 1,
#    ('clot', 'leg'): 1,
#    ('cold', 'cough'): 1,
#    ('common', 'caus'): 1,
#    ('complet', 'at'): 1,
#    ('condit', 'common'): 1,
#    ('condit', 'involv'): 1,
#    ('cough', 'ever'): 1,
#    ('cough', 'gone'): 1,
#    ('cough', 'pretti'): 1,
#    ('cramp', 'br'): 2,
#    ('day', 'instead'): 1,
#    ('deep', 'vein'): 1,
#    ('deficit', 'hyperact'): 1,
#    ('diabet', 'br'): 2,
#    ('diabet', 'herbal'): 1,
#    ('diabet', 'reason'): 1,
#    ('diseas', 'associ'): 1,
#    ('disord', 'adhd'): 1,
#    ('doctor', 'told'): 1,
#    ('dysfunct', 'ed'): 1,
#    ('dysmenorrhea', 'br'): 1,
#    ('ed', 'br'): 1,
#    ('effect', 'free'): 1,
#    ('effect', 'treat'): 1,
#    ('erectil', 'dysfunct'): 1,
#    ('ever', 'sinc'): 1,
#    ('extract', 'pine'): 1,
#    ('eye', 'condit'): 1,
#    ('far', 'main'): 1,
#    ('free', 'radic'): 1,
#    ('free', 'sampl'): 1,
#    ('gl', 'xv1lp'): 1,
#    ('gone', 'away'): 1,
#    ('gone', 'yay'): 1,
#    ('goo', 'gl'): 1,
#    ('got', 'sick'): 1,
#    ('great', 'stuff'): 1,
#    ('he', 'told'): 1,
#    ('heal', 'i'): 1,
#    ('heart', 'attack'): 1,
#    ('help', 'diabet'): 1,
#    ('herbal', 'treatment'): 1,
#    ('high', 'blood'): 1,
#    ('high', 'cholesterol'): 1,
#    ('hope', 'help'): 2,
#    ('hope', 'i'): 1,
#    ('hyperact', 'disord'): 1,
#    ('hypertens', 'br'): 1,
#    ('i', 'ad'): 1,
#    ('i', 'also'): 1,
#    ('i', 'ask'): 1,
#    ('i', 'bought'): 1,
#    ('i', 'got'): 1,
#    ('i', 'hope'): 1,
#    ('i', 'notic'): 1,
#    ('i', 'plan'): 1,
#    ('i', 'report'): 1,
#    ('i', 'start'): 1,
#    ('i', 'take'): 1,
#    ('i', 'the'): 1,
#    ('i', 'tri'): 1,
#    ('i', 'use'): 1,
#    ('impot', 'also'): 1,
#    ('improv', 'athlet'): 1,
#    ('infertil', 'br'): 1,
#    ('instead', 'i'): 1,
#    ('insuffici', 'condit'): 1,
#    ('involv', 'leg'): 1,
#    ('itch', 'skin'): 1,
#    ('januari', 'year'): 1,
#    ('known', 'erectil'): 1,
#    ('leg', 'cramp'): 2,
#    ('leg', 'deep'): 1,
#    ('leg', 'swell'): 1,
#    ('life', 'one'): 1,
#    ('like', 'allergi'): 1,
#    ('longev', 'potenti'): 1,
#    ('main', 'thing'): 1,
#    ('male', 'infertil'): 1,
#    ('menstrual', 'period'): 1,
#    ('month', 'cough'): 1,
#    ('month', 'far'): 1,
#    ('morn', 'my'): 1,
#    ('much', 'gone'): 1,
#    ('my', 'doctor'): 1,
#    ('my', 'person'): 1,
#    ('neither', 'i'): 1,
#    ('night', 'morn'): 1,
#    ('notic', 'allergi'): 1,
#    ('one', 'veggi'): 1,
#    ('pain', 'back'): 1,
#    ('pain', 'itch'): 1,
#    ('pain', 'leg'): 1,
#    ('pain', 'menstrual'): 1,
#    ('pain', 'pelvic'): 1,
#    ('past', 'month'): 1,
#    ('pelvic', 'pain'): 1,
#    ('perform', 'br'): 1,
#    ('period', 'dysmenorrhea'): 1,
#    ('person', 'physician'): 1,
#    ('physician', 'recommend'): 1,
#    ('pine', 'bark'): 1,
#    ('plan', 'starttak'): 1,
#    ('potenti', 'life'): 1,
#    ('pregnanc', 'pain'): 1,
#    ('pressur', 'hypertens'): 1,
#    ('pretti', 'bad'): 1,
#    ('pretti', 'much'): 1,
#    ('prevent', 'br'): 1,
#    ('prevent', 'circulatori'): 1,
#    ('provid', 'prevent'): 1,
#    ('pycnogenol', 'also'): 1,
#    ('pycogenol', 'month'): 1,
#    ('pycogenol', 'thing'): 1,
#    ('radic', 'also'): 1,
#    ('reason', 'i'): 1,
#    ('recommend', 'i'): 1,
#    ('regimen', 'add'): 1,
#    ('regimen', 'vitamin'): 1,
#    ('report', 'back'): 1,
#    ('retinopathi', 'eye'): 1,
#    ('said', 'improv'): 1,
#    ('sampl', 'great'): 1,
#    ('see', 'benefit'): 1,
#    ('sick', 'pretti'): 1,
#    ('sinc', 'night'): 1,
#    ('skin', 'chang'): 1,
#    ('so', 'tell'): 1,
#    ('soon', 'i'): 1,
#    ('start', 'take'): 1,
#    ('starttak', 'twice'): 1,
#    ('stroke', 'br'): 1,
#    ('stuff', 'br'): 1,
#    ('supplement', 'past'): 1,
#    ('swell', '3'): 1,
#    ('take', 'hope'): 1,
#    ('take', 'pycogenol'): 1,
#    ('tell', 'cant'): 1,
#    ('the', 'pycogenol'): 1,
#    ('thing', 'i'): 2,
#    ('thrombosi', 'br'): 1,
#    ('time', 'i'): 1,
#    ('told', 'extract'): 1,
#    ('told', 'like'): 1,
#    ('treat', '50'): 1,
#    ('treatment', 'regimen'): 1,
#    ('tri', 'i'): 1,
#    ('twice', 'day'): 1,
#    ('type', '2'): 1,
#    ('use', 'type'): 1,
#    ('varicos', 'vein'): 1,
#    ('veggi', 'cap'): 1,
#    ('vein', 'pain'): 1,
#    ('vein', 'thrombosi'): 1,
#    ('venous', 'insuffici'): 1,
#    ('vitamin', 'supplement'): 1,
#    ('whatev', 'i'): 1,
#    ('xv1lp', '10'): 1,
#    ('yay', 'i'): 1,
#    ('year', 'i'): 1},
#   'fake'),
#  ({('best', 'way'): 1,
#    ('daili', 'tall'): 1,
#    ('glass', 'water'): 1,
#    ('glow', 'use'): 1,
#    ('great', 'skin'): 1,
#    ('i', 'take'): 1,
#    ('it', 'best'): 1,
#    ('it', 'true'): 1,
#    ('like', 'glow'): 1,
#    ('look', 'softer'): 1,
#    ('my', 'skin'): 1,
#    ('pill', 'daili'): 1,
#    ('product', 'work'): 1,
#    ('recommend', 'product'): 1,
#    ('refresh', 'skin'): 1,
#    ('restor', 'refresh'): 1,
#    ('skin', 'i'): 1,
#    ('skin', 'look'): 1,
#    ('skin', 'within'): 1,
#    ('softer', 'like'): 1,
#    ('take', 'pill'): 1,
#    ('tall', 'glass'): 1,
#    ('true', 'recommend'): 1,
#    ('water', 'it'): 1,
#    ('way', 'restor'): 1,
#    ('within', 'my'): 1,
#    ('work', 'great'): 1},
#   'fake'),
#  ({('ad', 'towel'): 1,
#    ('almost', 'dark'): 1,
#    ('also', 'darker'): 1,
#    ('behind', 'also'): 1,
#    ('bring', 'color'): 1,
#    ('color', 'almost'): 1,
#    ('color', 'look'): 1,
#    ('curtain', 'littl'): 1,
#    ('dark', 'i'): 1,
#    ('darker', 'color'): 1,
#    ('differ', 'shade'): 1,
#    ('fine', 'price'): 1,
#    ('i', 'ad'): 1,
#    ('i', 'would'): 1,
#    ('like', 'work'): 1,
#    ('liner', 'behind'): 1,
#    ('littl', 'thinner'): 1,
#    ('look', 'nice'): 1,
#    ('price', 'liner'): 1,
#    ('rug', 'differ'): 1,
#    ('shade', 'bring'): 1,
#    ('shower', 'curtain'): 1,
#    ('thinner', 'i'): 1,
#    ('towel', 'rug'): 1,
#    ('work', 'fine'): 1,
#    ('would', 'like'): 1},
#   'fake'),
#  ({('bass', 'decent'): 1,
#    ('budget', 'surpris'): 1,
#    ('clear', 'even'): 1,
#    ('convent', 'i'): 1,
#    ('decent', 'perfect'): 1,
#    ('decent', 'speaker'): 1,
#    ('dorm', 'room'): 1,
#    ('even', 'set'): 1,
#    ('good', 'the'): 1,
#    ('got', 'budget'): 1,
#    ('i', 'got'): 1,
#    ('i', 'like'): 1,
#    ('i', 'look'): 1,
#    ('i', 'use'): 1,
#    ('it', 'look'): 1,
#    ('like', 'decent'): 1,
#    ('look', 'pretti'): 1,
#    ('look', 'someth'): 1,
#    ('max', 'volum'): 1,
#    ('parti', 'it'): 1,
#    ('perfect', 'roommat'): 1,
#    ('pretti', 'convent'): 1,
#    ('rather', 'stylish'): 1,
#    ('room', 'i'): 1,
#    ('roommat', 'slumber'): 1,
#    ('set', 'i'): 1,
#    ('set', 'max'): 1,
#    ('slumber', 'parti'): 1,
#    ('someth', 'rather'): 1,
#    ('sound', 'clear'): 1,
#    ('speaker', 'set'): 1,
#    ('surpris', 'good'): 1,
#    ('the', 'sound'): 1,
#    ('use', 'dorm'): 1,
#    ('volum', 'bass'): 1},
#   'fake'),
#  ({('appear', 'it'): 1,
#    ('care', 'either'): 1,
#    ('clean', 'i'): 1,
#    ('either', 'way'): 1,
#    ('i', 'need'): 1,
#    ('i', 'realli'): 1,
#    ('it', 'part'): 1,
#    ('part', 'clean'): 1,
#    ('realli', 'care'): 1,
#    ('scent', 'appear'): 1,
#    ('way', 'scent'): 1},
#   'fake'),
#  ({('abil', 'transfer'): 1,
#    ('also', 'love'): 1,
#    ('brais', 'great'): 1,
#    ('brown', 'carmal'): 1,
#    ('carmal', 'meat'): 1,
#    ('dutch', 'oven'): 1,
#    ('easi', 'cleanup'): 1,
#    ('greas', 'splatter'): 1,
#    ('great', 'brown'): 1,
#    ('great', 'soup'): 1,
#    ('high', 'greas'): 1,
#    ('i', 'also'): 1,
#    ('it', 'great'): 1,
#    ('larg', 'dutch'): 1,
#    ('larg', 'high'): 1,
#    ('love', 'abil'): 1,
#    ('meat', 'larg'): 1,
#    ('oven', 'it'): 1,
#    ('oven', 'roast'): 1,
#    ('roast', 'brais'): 1,
#    ('search', 'larg'): 1,
#    ('soup', 'easi'): 1,
#    ('splatter', 'stove'): 1,
#    ('stove', 'i'): 1,
#    ('transfer', 'oven'): 1},
#   'fake'),
#  ({('acceler', 'hair'): 1,
#    ('continu', 'use'): 1,
#    ('feel', 'like'): 1,
#    ('hair', 'i'): 1,
#    ('hair', 'loss'): 1,
#    ('high', 'hope'): 1,
#    ('hope', 'thicken'): 1,
#    ('i', 'continu'): 1,
#    ('i', 'feel'): 1,
#    ('i', 'high'): 1,
#    ('instead', 'left'): 1,
#    ('left', 'less'): 1,
#    ('less', 'hair'): 1,
#    ('like', 'acceler'): 1,
#    ('loss', 'i'): 1,
#    ('remaind', 'refund'): 1,
#    ('return', 'remaind'): 1,
#    ('shampoo', 'instead'): 1,
#    ('thicken', 'shampoo'): 1,
#    ('use', 'return'): 1},
#   'fake'),
#  ({('100', 'anyon'): 1,
#    ('5', 'htp'): 1,
#    ('also', 'begun'): 1,
#    ('anxieti', 'depress'): 2,
#    ('anxieti', 'kava'): 1,
#    ('anxieti', 'stress'): 1,
#    ('anyon', 'look'): 1,
#    ('asin', 'b00f5jjloc'): 1,
#    ('attack', 'boost'): 1,
#    ('b00f5jjloc', 'xanrx'): 1,
#    ('back', 'guarante'): 1,
#    ('beat', 'anxieti'): 1,
#    ('begun', 'medit'): 1,
#    ('begun', 'use'): 1,
#    ('between', 'three'): 1,
#    ('book', 'asin'): 1,
#    ('book', 'help'): 1,
#    ('boost', 'mood'): 1,
#    ('conjunct', 'book'): 1,
#    ('deal', 'anxieti'): 1,
#    ('depress', 'give'): 1,
#    ('depress', 'it'): 1,
#    ('depress', 'panic'): 1,
#    ('dietari', 'supplement'): 1,
#    ('discuss', 'book'): 1,
#    ('gaba', 'money'): 1,
#    ('give', 'xanrx'): 1,
#    ('help', 'conjunct'): 1,
#    ('help', 'deal'): 1,
#    ('help', 'i'): 1,
#    ('htp', 'theanin'): 1,
#    ('huge', 'help'): 1,
#    ('i', 'also'): 1,
#    ('i', 'begun'): 1,
#    ('improv', '100'): 1,
#    ('increas', 'relax'): 1,
#    ('it', 'huge'): 1,
#    ('kava', '5'): 1,
#    ('kava', 'kava'): 1,
#    ('life', 'improv'): 1,
#    ('look', 'otc'): 1,
#    ('mani', 'techniqu'): 1,
#    ('medit', 'slowli'): 1,
#    ('money', 'back'): 1,
#    ('mood', 'increas'): 1,
#    ('otc', 'supplement'): 2,
#    ('panic', 'attack'): 1,
#    ('realli', 'help'): 1,
#    ('reduc', 'symptom'): 1,
#    ('relax', 'beat'): 1,
#    ('replac', 'zoloft'): 1,
#    ('slowli', 'work'): 1,
#    ('stress', 'depress'): 1,
#    ('supplement', 'anxieti'): 1,
#    ('supplement', 'between'): 1,
#    ('supplement', 'reduc'): 1,
#    ('symptom', 'anxieti'): 1,
#    ('techniqu', 'discuss'): 1,
#    ('theanin', 'gaba'): 1,
#    ('thing', 'life'): 1,
#    ('three', 'thing'): 1,
#    ('tri', 'realli'): 1,
#    ('use', 'mani'): 1,
#    ('work', 'replac'): 1,
#    ('xanrx', 'dietari'): 1,
#    ('xanrx', 'tri'): 1,
#    ('zoloft', 'otc'): 1},
#   'fake'),
#  ({('also', 'great'): 1,
#    ('anyth', 'it'): 1,
#    ('art', 'paper'): 1,
#    ('brother', 'realli'): 1,
#    ('draw', 'anyth'): 1,
#    ('exact', 'i'): 1,
#    ('great', 'present'): 1,
#    ('great', 'price'): 1,
#    ('i', 'look'): 1,
#    ('it', 'also'): 1,
#    ('look', 'made'): 1,
# ...
#    ('laptop', 'pricey'): 1,
#    ('laptop', 'run'): 1,
#    ('like', '3'): 1,
#    ('littl', 'it'): 1,
#    ('lot', 'carri'): 1,
#    ('move', 'even'): 1,
#    ('my', 'back'): 1,
#    ('my', 'con'): 1,
#    ('near', 'happen'): 1,
#    ('peopl', 'diss'): 1,
#    ('photoshop', 'cs5'): 1,
#    ('pricey', 'fit'): 1,
#    ('problem', 'i'): 1,
#    ('program', 'i'): 1,
#    ('ran', 'smooth'): 1,
#    ('realli', 'fast'): 1,
#    ('replac', 'but'): 1,
#    ('run', 'adob'): 1,
#    ('run', 'smooth'): 1,
#    ('seat', 'lap'): 1,
#    ('smooth', 'i'): 1,
#    ('smooth', 'the'): 1,
#    ('sometim', 'move'): 1,
#    ('still', 'great'): 1,
#    ('still', 'run'): 1,
#    ('student', 'like'): 1,
#    ('the', 'charg'): 1,
#    ('the', 'laptop'): 1,
#    ('the', 'touchpad'): 1,
#    ('touchpad', 'annoy'): 1,
#    ('use', 'game'): 1,
#    ('want', 'bring'): 1,
#    ('whole', 'day'): 1,
#    ('work', 'replac'): 1,
#    ('year', 'ago'): 1,
#    ('year', 'batteri'): 1},
#   'fake'),
#  ({('34', 'cool'): 1,
#    ('34', 'it'): 1,
#    ('bought', 'far'): 1,
#    ('bought', 'second'): 1,
#    ('bought', 'son'): 1,
#    ('buckl', 'pretti'): 1,
#    ('cool', '34'): 1,
#    ('cup', 'holder'): 1,
#    ('easi', 'get'): 1,
#    ('far', 'great'): 1,
#    ('flame', '34'): 1,
#    ('get', 'buckl'): 1,
#    ('great', 'i'): 1,
#    ('holder', 'bought'): 1,
#    ('i', 'bought'): 1,
#    ('i', 'wish'): 1,
#    ('it', 'easi'): 1,
#    ('much', 'anyway'): 1,
#    ('much', 'the'): 1,
#    ('pretti', 'much'): 1,
#    ('probabl', 'use'): 1,
#    ('second', 'vehicl'): 1,
#    ('son', 'think'): 1,
#    ('the', 'thing'): 1,
#    ('thing', 'i'): 1,
#    ('think', 'flame'): 1,
#    ('use', 'much'): 1,
#    ('vehicl', 'probabl'): 1,
#    ('we', 'bought'): 1,
#    ('wish', 'cup'): 1},
#   'fake'),
#  ({('anymor', 'bottl'): 1,
#    ('bottl', 'gone'): 1,
#    ('but', 'fade'): 1,
#    ('buy', 'anymor'): 1,
#    ('cologn', 'smell'): 1,
#    ('coupl', 'hour'): 1,
#    ('everi', 'coupl'): 1,
#    ('fade', 'i'): 1,
#    ('fade', 'quick'): 1,
#    ('girlfriend', 'but'): 1,
#    ('hassl', 'reappli'): 1,
#    ('hour', 'fade'): 1,
#    ('i', 'buy'): 1,
#    ('i', 'like'): 1,
#    ('like', 'way'): 1,
#    ('quick', 'hassl'): 1,
#    ('reappli', 'everi'): 1,
#    ('smell', 'girlfriend'): 1,
#    ('way', 'cologn'): 1},
#   'fake'),
#  ({('bottom', 'left'): 1,
#    ('catch', 'spill'): 1,
#    ('complet', 'find'): 1,
#    ('contain', 'made'): 1,
#    ('eat', 'noodl'): 1,
#    ('end', 'serv'): 1,
#    ('everi', 'time'): 1,
#    ('fell', 'spill'): 1,
#    ('find', 'eat'): 1,
#    ('gravit', 'bottom'): 1,
#    ('heat', 'particular'): 1,
#    ('i', 'heat'): 1,
#    ('if', 'catch'): 1,
#    ('left', 'untasti'): 1,
#    ('made', 'pop'): 1,
#    ('mash', 'end'): 1,
#    ('microwav', 'contain'): 1,
#    ('noodl', 'gravit'): 1,
#    ('noodl', 'mash'): 1,
#    ('particular', 'soup'): 1,
#    ('pasti', 'noodl'): 1,
#    ('pop', 'sound'): 1,
#    ('pop', 'turn'): 1,
#    ('sound', 'pop'): 1,
#    ('soup', 'microwav'): 1,
#    ('spill', 'complet'): 1,
#    ('spill', 'if'): 1,
#    ('time', 'i'): 1,
#    ('tray', 'fell'): 1,
#    ('turn', 'tray'): 1,
#    ('untasti', 'pasti'): 1},
#   'fake'),
#  ({('abl', 'recogn'): 1,
#    ('card', 'sometim'): 1,
#    ('disappoint', 'even'): 1,
#    ('even', 'price'): 1,
#    ('exchang', 'polici'): 1,
#    ('exchang', 'product'): 1,
#    ('i', 'disappoint'): 1,
#    ('i', 'tri'): 1,
#    ('mare', 'i'): 1,
#    ('my', 'phone'): 1,
#    ('night', 'mare'): 1,
#    ('phone', 'abl'): 1,
#    ('polici', 'night'): 1,
#    ('price', 'quit'): 1,
#    ('product', 'refund'): 1,
#    ('quit', 'good'): 1,
#    ('recogn', 'card'): 1,
#    ('refund', 'exchang'): 1,
#    ('sometim', 'transfer'): 1,
#    ('speed', 'terribl'): 1,
#    ('terribl', 'therefor'): 1,
#    ('therefor', 'i'): 1,
#    ('transfer', 'speed'): 1,
#    ('tri', 'exchang'): 1},
#   'fake'),
#  ({('actual', 'sound'): 1,
#    ('br', 'br'): 1,
#    ('br', 'now'): 1,
#    ('cigar', 'someth'): 1,
#    ('i', 'actual'): 1,
#    ('i', 'know'): 1,
#    ('i', 'previous'): 1,
#    ('i', 'talk'): 1,
#    ('idea', 'the'): 1,
#    ('know', 'someth'): 1,
#    ('like', 'i'): 1,
#    ('men', 'cigar'): 1,
#    ('now', 'i'): 2,
#    ('previous', 'idea'): 1,
#    ('put', 'sir'): 1,
#    ('sir', 'br'): 1,
#    ('someth', 'i'): 1,
#    ('sound', 'like'): 1,
#    ('talk', 'men'): 1,
#    ('talk', 'would'): 1,
#    ('the', 'talk'): 1,
#    ('would', 'put'): 1},
#   'fake'),
#  ({('a', 'complet'): 1,
#    ('apart', 'it'): 1,
#    ('bought', 'use'): 1,
#    ('came', 'hing'): 1,
#    ('complet', 'came'): 1,
#    ('complet', 'fell'): 1,
#    ('complet', 'wast'): 1,
#    ('coupl', 'month'): 1,
#    ('drawer', 'complet'): 1,
#    ('fell', 'apart'): 1,
#    ('get', 'stuck'): 1,
#    ('hing', 'a'): 1,
#    ('i', 'bought'): 1,
#    ('it', 'start'): 1,
#    ('month', 'complet'): 1,
#    ('one', 'drawer'): 1,
#    ('start', 'get'): 1,
#    ('stuck', 'one'): 1,
#    ('undergar', 'coupl'): 1,
#    ('use', 'undergar'): 1,
#    ('wast', 'money'): 1},
#   'fake'),
#  ({('again', 'great'): 1,
#    ('case', 'long'): 1,
#    ('case', 'pain'): 1,
#    ('dremel', 'flex'): 1,
#    ('dremel', 'tri'): 1,
#    ('fit', 'rtx'): 1,
#    ('flex', 'shaft'): 1,
#    ('for', 'interest'): 1,
#    ('great', 'product'): 1,
#    ('great', 'tool'): 1,
#    ('happi', 'it'): 1,
#    ('i', 'happi'): 1,
#    ('interest', 'dremel'): 1,
#    ('it', 'three'): 1,
#    ('long', 'tool'): 1,
#    ('main', 'speed'): 1,
#    ('pain', 'case'): 1,
#    ('perform', 'well'): 1,
#    ('regardless', 'dremel'): 1,
#    ('rtx', 'great'): 1,
#    ('rtx', 'regardless'): 1,
#    ('select', 'three'): 1,
#    ('shaft', 'fit'): 1,
#    ('soft', 'case'): 1,
#    ('speed', 'again'): 1,
#    ('speed', 'select'): 1,
#    ('tell', 'the'): 1,
#    ('the', 'rtx'): 1,
#    ('the', 'soft'): 1,
#    ('three', 'main'): 1,
#    ('three', 'speed'): 1,
#    ('tool', 'for'): 1,
#    ('tool', 'perform'): 1,
#    ('tri', 'tell'): 1,
#    ('well', 'i'): 1},
#   'fake'),
#  ({('abus', 'commit'): 1,
#    ('abus', 'know'): 1,
#    ('abus', 'stori'): 1,
#    ('ad', 'whole'): 1,
#    ('adelin', 'eventu'): 1,
#    ('adelin', 'yen'): 1,
#    ('affect', 'imag'): 1,
#    ('as', 'daughter'): 1,
#    ('back', 'home'): 1,
#    ('boundari', 'she'): 1,
#    ('china', 'england'): 1,
#    ('chines', 'famili'): 1,
#    ('chines', 'heritag'): 1,
#    ('commit', 'this'): 1,
#    ('cruel', 'eurasian'): 1,
#    ('cultur', 'abus'): 1,
#    ('cultur', 'affect'): 1,
#    ('daughter', 'wealthi'): 1,
#    ('econom', 'boundari'): 1,
#    ('element', 'tradit'): 1,
#    ('england', 'us'): 1,
#    ('eurasian', 'mother'): 1,
#    ('eventu', 'move'): 1,
#    ('famili', 'adelin'): 1,
#    ('famili', 'give'): 1,
#    ('famili', 'it'): 1,
#    ('famili', 'tie'): 1,
#    ('give', 'insight'): 1,
#    ('heritag', 'as'): 1,
#    ('home', 'it'): 1,
#    ('imag', 'famili'): 1,
#    ('insight', 'abus'): 1,
#    ('interest', 'look'): 1,
#    ('interest', 'read'): 1,
#    ('interest', 'stori'): 1,
#    ('it', 'interest'): 2,
#    ('know', 'econom'): 1,
#    ('look', 'chines'): 1,
#    ('look', 'three'): 1,
#    ('mah', 'tell'): 1,
#    ('mother', 'ad'): 1,
#    ('move', 'china'): 1,
#    ('new', 'element'): 1,
#    ('new', 'look'): 1,
#    ('prepar', 'terribl'): 1,
#    ('preserv', 'famili'): 1,
#    ('read', 'prepar'): 1,
#    ('she', 'cruel'): 1,
#    ('stori', 'cultur'): 1,
#    ('tell', 'interest'): 1,
#    ('terribl', 'abus'): 1,
#    ('this', 'new'): 1,
#    ('three', 'cultur'): 1,
#    ('tie', 'back'): 1,
#    ('tradit', 'famili'): 1,
#    ('tri', 'preserv'): 1,
#    ('us', 'tri'): 1,
#    ('wealthi', 'chines'): 1,
#    ('whole', 'new'): 1,
#    ('yen', 'mah'): 1},
#   'fake'),
#  ({('amount', 'time'): 1,
#    ('attent', 'gradual'): 1,
#    ('attent', 'long'): 1,
#    ('attent', 'span'): 1,
#    ('bond', 'so'): 1,
#    ('book', 'make'): 1,
#    ('book', 'much'): 1,
#    ('but', 'teach'): 1,
#    ('command', 'book'): 1,
#    ('command', 'exhaust'): 1,
#    ('control', 'dog'): 1,
#    ('differ', 'provid'): 1,
#    ('distract', 'maintain'): 1,
#    ('dog', 'attent'): 1,
#    ('dog', 'learn'): 1,
#    ('exhaust', 'often'): 1,
#    ('expect', 'puppi'): 1,
#    ('first', 'minim'): 1,
#    ('full', 'attent'): 1,
#    ('gradual', 'increas'): 1,
#    ('great', 'opportun'): 1,
#    ('help', 'i'): 1,
#    ('i', 'learn'): 1,
#    ('i', 'tri'): 1,
#    ('imposs', 'but'): 1,
#    ('increas', 'amount'): 1,
#    ('keep', 'mind'): 1,
#    ('keep', 'session'): 1,
#    ('learn', 'keep'): 1,
#    ('learn', 'obedi'): 1,
#    ('long', 'period'): 1,
#    ('maintain', 'dog'): 1,
#    ('make', 'world'): 1,
#    ('mind', 'puppi'): 1,
#    ('minim', 'distract'): 1,
#    ('much', 'help'): 1,
#    ('near', 'imposs'): 1,
#    ('obedi', 'command'): 1,
#    ('often', 'near'): 1,
#    ('opportun', 'bond'): 1,
#    ('period', 'time'): 1,
#    ('provid', 'great'): 1,
#    ('puppi', 'full'): 1,
#    ('puppi', 'short'): 1,
#    ('session', 'short'): 1,
#    ('short', 'attent'): 1,
#    ('short', 'first'): 1,
#    ('simpl', 'command'): 1,
#    ('so', 'thank'): 1,
#    ('span', 'unreason'): 1,
#    ('spent', 'train'): 1,
#    ('teach', 'simpl'): 1,
#    ('thank', 'book'): 1,
#    ('time', 'keep'): 1,
#    ('time', 'spent'): 1,
#    ('train', 'day'): 1,
#    ('tri', 'control'): 1,
#    ('unreason', 'expect'): 1,
#    ('world', 'differ'): 1},
#   'fake'),
#  ({('anyway', 'great'): 1,
#    ('br', 'anyway'): 1,
#    ('bubbl', 'come'): 1,
#    ('come', 'second'): 1,
#    ('day', 'girlfriend'): 2,
#    ('girlfriend', 'bought'): 1,
#    ('girlfriend', 'stuck'): 1,
#    ('great', 'last'): 1,
#    ('i', 'someth'): 1,
#    ('i', 'think'): 1,
#    ('kitchen', 'wall'): 1,
#    ('last', 'sad'): 1,
#    ('sad', 'us'): 1,
#    ('second', 'day'): 1,
#    ('someth', 'wrong'): 1,
#    ('stuck', 'kitchen'): 1,
#    ('think', 'i'): 1,
#    ('us', 'day'): 1,
#    ('wall', 'br'): 1,
#    ('wrong', 'bubbl'): 1},
#   'fake'),
#  ({('1', 'year'): 1,
#    ('best', 'mp3'): 1,
#    ('given', 'price'): 1,
#    ('mp3', 'player'): 1,
#    ('player', 'given'): 1,
#    ('price', 'problem'): 1,
#    ('problem', 'till'): 1,
#    ('product', '1'): 1,
#    ('review', 'product'): 1,
#    ('use', 'best'): 1,
#    ('year', 'use'): 1},
#   'fake'),
#  ({('alon', 'enough'): 1,
#    ('buy', 'i'): 1,
#    ('cheaper', 'i'): 1,
#    ('enough', 'justifi'): 1,
#    ('expens', 'it'): 1,
#    ('expens', 'price'): 1,
#    ('hair', 'same'): 1,
#    ('here', 'take'): 1,
#    ('i', 'afford'): 1,
#    ('i', 'like'): 1,
#    ('i', 'probabl'): 1,
#    ('if', 'cheaper'): 1,
#    ('it', 'regular'): 1,
#    ('it', 'thing'): 1,
#    ('justifi', 'expens'): 1,
#    ('like', 'smell'): 1,
#    ('price', 'tag'): 1,
#    ('probabl', 'buy'): 1,
#    ('regular', 'shampoo'): 1,
#    ('same', 'i'): 1,
#    ('shampoo', 'expens'): 1,
#    ('shampoo', 'it'): 1,
#    ('smell', 'alon'): 1,
#    ('tag', 'if'): 1,
#    ('take', 'shampoo'): 1,
#    ('thing', 'hair'): 1},
#   'fake'),
#  ({('around', 'goe'): 1,
#    ('feel', 'like'): 1,
#    ('goe', 'oh'): 1,
#    ('guess', 'son'): 1,
#    ('hang', 'around'): 1,
#    ('i', 'feel'): 1,
#    ('i', 'guess'): 1,
#    ('leav', 'hang'): 1,
#    ('like', 'stomp'): 1,
#    ('love', 'i'): 1,
#    ('matter', 'i'): 1,
#    ('oh', 'well'): 1,
#    ('realli', 'matter'): 1,
#    ('son', 'love'): 1,
#    ('stomp', 'leav'): 1,
#    ('what', 'realli'): 1},
#   'fake'),
#  ({('alway', 'love'): 1,
#    ('babi', 'alway'): 1,
#    ('easi', 'store'): 1,
#    ('easi', 'travel'): 1,
#    ('easi', 'warm'): 1,
#    ('expens', 'get'): 1,
#    ('food', 'great'): 1,
#    ('get', 'pay'): 1,
#    ('great', 'my'): 1,
#    ('it', 'littl'): 1,
#    ('littl', 'expens'): 1,
#    ('love', 'veri'): 1,
#    ('my', 'babi'): 1,
#    ('pay', 'opinion'): 1,
#    ('store', 'it'): 1,
#    ('this', 'food'): 1,
#    ('travel', 'easi'): 1,
#    ('veri', 'easi'): 1,
#    ('warm', 'easi'): 1},
#   'fake'),
#  ({('alway', 'thought'): 1,
#    ('anymor', 'recommend'): 1,
#    ('armi', 'rubber'): 1,
#    ('but', 'now'): 1,
#    ('case', 'armi'): 1,
#    ('case', 'i'): 1,
#    ('damag', 'but'): 1,
#    ('disappoint', 'veri'): 1,
#    ('dust', 'scratch'): 1,
#    ('fall', 'damag'): 1,
#    ('flexibl', 'iphon'): 1,
#    ('i', 'alway'): 1,
#    ('i', 'case'): 1,
#    ('i', 'maintain'): 1,
#    ('i', 'worri'): 1,
#    ('iphon', 'i'): 1,
#    ('it', 'never'): 1,
#    ('love', 'love'): 2,
#    ('love', 'no'): 1,
#    ('maintain', 'protect'): 1,
#    ('never', 'disappoint'): 1,
#    ('no', 'question'): 1,
#    ('now', 'i'): 1,
#    ('phone', 'dust'): 1,
#    ('protect', 'phone'): 1,
#    ('qualiti', 'servic'): 1,
#    ('question', 'qualiti'): 1,
#    ('rubber', 'case'): 1,
#    ('scratch', 'fall'): 1,
#    ('servic', 'it'): 1,
#    ('thought', 'i'): 1,
#    ('veri', 'flexibl'): 1,
#    ('worri', 'anymor'): 1},
#   'fake'),
#  ({('28', 'pound'): 1,
#    ('50', 'pound'): 1,
#    ('a', 'lot'): 1,
#    ('actual', 'great'): 1,
#    ('blood', 'pressur'): 1,
#    ('br', 'br'): 4,
#    ('br', 'i'): 1,
#    ('br', 'if'): 1,
#    ('br', 'on'): 1,
#    ('br', 'so'): 1,
#    ('buy', 'patient'): 1,
#    ('buy', 'raspberri'): 1,
#    ('caus', 'lot'): 1,
#    ('chest', 'pain'): 1,
#    ('coupl', 'month'): 1,
#    ('crazi', 'fault'): 1,
#    ('diabet', 'type'): 1,
#    ('diarrhea', 'chest'): 1,
#    ('diseas', 'often'): 1,
#    ('effect', 'no'): 1,
#    ('either', 'some'): 1,
#    ('even', 'take'): 1,
#    ('expect', 'someth'): 1,
#    ('famili', 'stuff'): 1,
#    ('faster', 'i'): 1,
#    ('fat', 'i'): 1,
#    ('fat', 'peopl'): 1,
#    ('fault', 'product'): 1,
#    ('flatul', 'either'): 1,
#    ('get', 'diabet'): 1,
#    ('get', 'diseas'): 1,
#    ('get', 'fat'): 1,
#    ('get', 'high'): 1,
#    ('get', 'rid'): 1,
#    ('get', 'so'): 1,
#    ('great', 'product'): 1,
#    ('guy', 'it'): 1,
#    ('hand', 'i'): 1,
#    ('headach', 'diarrhea'): 1,
#    ('high', 'blood'): 1,
#    ('i', 'expect'): 1,
#    ('i', 'flatul'): 1,
#    ('i', 'impati'): 1,
#    ('i', 'know'): 2,
#    ('i', 'lost'): 2,
#    ('i', 'never'): 1,
#    ('i', 'realli'): 1,
#    ('i', 'singl'): 1,
#    ('i', 'take'): 1,
#    ('i', 'think'): 1,
#    ('i', 'took'): 1,
#    ('i', 'want'): 1,
#    ('if', 'peopl'): 1,
#    ('ii', 'get'): 1,
#    ('impati', 'guy'): 1,
#    ('instead', 'i'): 1,
#    ('it', 'took'): 1,
#    ('keton', 'i'): 1,
#    ('keton', 'late'): 1,
#    ('know', 'crazi'): 1,
#    ('know', 'still'): 1,
#    ('late', 'health'): 1,
#    ('like', '50'): 1,
#    ('like', 'weight'): 1,
#    ('live', 'longer'): 1,
#    ('longer', 'lose'): 1,
#    ('lose', 'faster'): 1,
#    ('lose', 'weight'): 2,
#    ('loss', 'stuff'): 1,
#    ('lost', '28'): 1,
#    ('lost', 'lot'): 1,
#    ('lost', 'much'): 1,
#    ('lot', 'br'): 2,
#    ('lot', 'weight'): 1,
#    ('make', 'oh'): 1,
#    ('month', 'i'): 2,
#    ('month', 'instead'): 1,
#    ('month', 'lose'): 1,
#    ('much', 'weight'): 1,
#    ('need', 'thin'): 1,
#    ('never', 'lost'): 1,
#    ('no', 'headach'): 1,
#    ('often', 'br'): 1,
#    ('often', 'fat'): 1,
#    ('oh', 'i'): 1,
#    ('on', 'hand'): 1,
#    ('pain', 'like'): 1,
#    ('patient', 'even'): 1,
#    ('peopl', 'buy'): 1,
#    ('peopl', 'famili'): 1,
#    ('peopl', 'get'): 1,
#    ('peopl', 'you'): 1,
#    ('pill', 'i'): 1,
#    ('pound', 'coupl'): 1,
#    ('pound', 'two'): 1,
#    ('pressur', 'often'): 1,
#    ('product', 'br'): 1,
#    ('product', 'i'): 1,
#    ('raspberri', 'keton'): 2,
#    ('realli', 'want'): 1,
#    ('rid', 'month'): 1,
#    ('side', 'effect'): 1,
#    ('singl', 'side'): 1,
#    ('so', 'actual'): 1,
#    ('so', 'buy'): 1,
#    ('some', 'pill'): 1,
#    ('someth', 'like'): 1,
#    ('still', 'a'): 1,
#    ('stuff', 'make'): 1,
#    ('stuff', 'need'): 1,
#    ('supplement', 'i'): 1,
#    ('take', 'raspberri'): 1,
#    ('take', 'supplement'): 1,
#    ('take', 'three'): 1,
#    ('thin', 'get'): 1,
#    ('thin', 'peopl'): 1,
#    ('thin', 'thin'): 1,
#    ('think', 'peopl'): 1,
#    ('three', 'month'): 1,
#    ('took', 'caus'): 1,
#    ('took', 'year'): 1,
#    ('two', 'month'): 1,
#    ('type', 'ii'): 1,
#    ('want', 'get'): 1,
#    ('want', 'lose'): 1,
#    ('weight', 'i'): 1,
#    ('weight', 'loss'): 1,
#    ('weight', 'take'): 1,
#    ('weight', 'thin'): 1,
#    ('weight', 'worth'): 1,
#    ('worth', 'live'): 1,
#    ('year', 'get'): 1,
#    ('you', 'get'): 1},
#   'fake'),
#  ({('2013', 'get'): 1,
#    ('299', 'may'): 1,
#    ('after', 'warranti'): 1,
#    ('anoth', 'one'): 1,
#    ('anyon', 'never'): 1,
#    ('anyway', 'i'): 1,
#    ('begin', 'mess'): 1,
#    ('drop', 'misus'): 1,
#    ('expect', 'last'): 1,
#    ('extend', 'warranti'): 1,
#    ('for', 'price'): 1,
#    ('get', 'extend'): 1,
#    ('i', 'expect'): 1,
#    ('i', 'purchas'): 1,
#    ('i', 'would'): 1,
#    ('ipad', 'mini'): 1,
#    ('it', 'never'): 1,
#    ('last', 'longer'): 1,
#    ('longer', 'it'): 1,
#    ('may', '2013'): 1,
#    ('mess', 'for'): 1,
#    ('mini', '299'): 1,
#    ('misus', 'anyway'): 1,
#    ('never', 'drop'): 1,
#    ('never', 'purchas'): 1,
#    ('price', 'i'): 1,
#    ('probabl', 'after'): 1,
#    ('purchas', 'anoth'): 1,
#    ('purchas', 'ipad'): 1,
#    ('ran', 'screen'): 1,
#    ('recommend', 'anyon'): 1,
#    ('screen', 'begin'): 1,
#    ('warranti', 'probabl'): 1,
#    ('warranti', 'ran'): 1,
#    ('would', 'recommend'): 1},
#   'fake'),
#  ...]
